# %%
import torch.optim as optim
import gymnasium as gym

from simple_ppo import PPO
from simple_ppo.policy import ContinuMlpPolicy
from simple_ppo.utils import evaluate, plot

# %%
policy = ContinuMlpPolicy(state_dim=17, action_dim=6, sd_init=0.4, sd_rng=(0.03, 0.5))
optimizer = optim.Adam(policy.parameters(), lr=0.0001)

# %%
env = gym.make('HalfCheetah-v4', render_mode=None, max_episode_steps=256)
env_eval = gym.make('HalfCheetah-v4', render_mode=None)

agent = PPO(policy, optimizer, env, env_eval,
            gamma=0.99, gae_lambda=0.95, n_step=2048, batch_size=64, n_epochs=16,
            clip_eps=0.1, vf_coef=1.0, ent_coef=0.001, max_grad_norm=1.0,
            eval_num=4)

log = agent.train(total_timesteps=500000)

env.close()
env_eval.close()
# Out:
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# | timestep   2048 | policy   +3.458 | value   +2.694 | entropy   +0.517 | reward   -53.1 |
# | timestep   4096 | policy   +3.690 | value   +2.521 | entropy   +0.541 | reward   -44.9 |
# | timestep   6144 | policy   +1.843 | value   +1.857 | entropy   +0.559 | reward   -43.2 |
# | timestep   8192 | policy   +2.394 | value   +2.005 | entropy   +0.575 | reward   -22.9 |
# | timestep  10240 | policy   +0.486 | value   +2.528 | entropy   +0.585 | reward   -20.3 |
# | timestep  12288 | policy   +0.047 | value   +2.282 | entropy   +0.585 | reward   -17.8 |
# | timestep  14336 | policy   +0.037 | value   +2.209 | entropy   +0.583 | reward   -15.2 |
# | timestep  16384 | policy   -0.837 | value   +2.074 | entropy   +0.578 | reward   -25.3 |
# | timestep  18432 | policy   -0.496 | value   +2.048 | entropy   +0.571 | reward   -14.4 |
# | timestep  20480 | policy   -1.177 | value   +2.341 | entropy   +0.561 | reward   -10.4 |
# | timestep  22528 | policy   -1.736 | value   +2.225 | entropy   +0.542 | reward   +41.5 |
# | timestep  24576 | policy   -2.354 | value   +2.491 | entropy   +0.522 | reward  +144.2 |
# | timestep  26624 | policy   -1.735 | value   +2.406 | entropy   +0.501 | reward  +206.0 |
# | timestep  28672 | policy   -1.983 | value   +2.424 | entropy   +0.477 | reward  +242.6 |
# | timestep  30720 | policy   -3.149 | value   +2.539 | entropy   +0.452 | reward  +274.5 |
# | timestep  32768 | policy   -2.716 | value   +2.665 | entropy   +0.429 | reward  +309.9 |
# | timestep  34816 | policy   -3.545 | value   +2.702 | entropy   +0.402 | reward  +327.7 |
# | timestep  36864 | policy   -2.573 | value   +2.743 | entropy   +0.379 | reward  +446.7 |
# | timestep  38912 | policy   -3.680 | value   +2.477 | entropy   +0.357 | reward  +495.6 |
# | timestep  40960 | policy   -3.882 | value   +2.393 | entropy   +0.333 | reward  +556.9 |
# | timestep  43008 | policy   -2.869 | value   +2.219 | entropy   +0.314 | reward  +556.2 |
# | timestep  45056 | policy   -2.168 | value   +3.234 | entropy   +0.301 | reward  +577.1 |
# | timestep  47104 | policy   -3.480 | value   +2.657 | entropy   +0.283 | reward  +669.0 |
# | timestep  49152 | policy   -3.240 | value   +2.030 | entropy   +0.256 | reward  +671.7 |
# | timestep  51200 | policy   -2.251 | value   +4.356 | entropy   +0.239 | reward  +638.4 |
# | timestep  53248 | policy   -4.335 | value   +2.864 | entropy   +0.223 | reward  +692.8 |
# | timestep  55296 | policy   -3.919 | value   +3.191 | entropy   +0.196 | reward  +768.2 |
# | timestep  57344 | policy   -1.931 | value   +3.808 | entropy   +0.179 | reward  +864.9 |
# | timestep  59392 | policy   -4.514 | value   +3.030 | entropy   +0.164 | reward  +869.2 |
# | timestep  61440 | policy   -1.921 | value   +3.017 | entropy   +0.146 | reward  +842.4 |
# | timestep  63488 | policy   -2.330 | value   +3.695 | entropy   +0.138 | reward  +780.9 |
# | timestep  65536 | policy   -4.215 | value   +2.778 | entropy   +0.124 | reward  +869.0 |
# | timestep  67584 | policy   -2.722 | value   +3.324 | entropy   +0.103 | reward +1123.0 |
# | timestep  69632 | policy   -1.194 | value   +3.937 | entropy   +0.092 | reward +1099.1 |
# | timestep  71680 | policy   -2.285 | value   +4.579 | entropy   +0.087 | reward  +879.7 |
# | timestep  73728 | policy   -4.428 | value   +2.737 | entropy   +0.071 | reward  +920.2 |
# | timestep  75776 | policy   -3.258 | value   +3.716 | entropy   +0.051 | reward +1100.2 |
# | timestep  77824 | policy   -4.118 | value   +3.306 | entropy   +0.036 | reward +1080.3 |
# | timestep  79872 | policy   -3.567 | value   +2.637 | entropy   +0.017 | reward +1002.8 |
# | timestep  81920 | policy   -3.812 | value   +2.981 | entropy   -0.002 | reward +1011.8 |
# | timestep  83968 | policy   -2.882 | value   +2.829 | entropy   -0.021 | reward +1124.1 |
# | timestep  86016 | policy   -4.365 | value   +2.864 | entropy   -0.040 | reward +1214.9 |
# | timestep  88064 | policy   -4.003 | value   +2.462 | entropy   -0.063 | reward +1294.0 |
# | timestep  90112 | policy   -3.765 | value   +3.774 | entropy   -0.082 | reward +1303.0 |
# | timestep  92160 | policy   -2.172 | value   +3.816 | entropy   -0.094 | reward +1310.0 |
# | timestep  94208 | policy   -4.021 | value   +2.652 | entropy   -0.110 | reward +1385.3 |
# | timestep  96256 | policy   -4.505 | value   +4.221 | entropy   -0.131 | reward +1367.2 |
# | timestep  98304 | policy   -4.235 | value   +4.000 | entropy   -0.148 | reward +1452.9 |
# | timestep 100352 | policy   -3.306 | value   +4.717 | entropy   -0.163 | reward +1489.0 |
# | timestep 102400 | policy   -1.053 | value   +4.686 | entropy   -0.170 | reward +1467.6 |
# | timestep 104448 | policy   -2.927 | value   +4.638 | entropy   -0.175 | reward +1501.9 |
# | timestep 106496 | policy   -2.617 | value   +3.201 | entropy   -0.188 | reward +1541.5 |
# | timestep 108544 | policy   -3.527 | value   +3.770 | entropy   -0.204 | reward +1623.5 |
# | timestep 110592 | policy   -4.300 | value   +3.042 | entropy   -0.224 | reward +1742.6 |
# | timestep 112640 | policy   -5.193 | value   +3.616 | entropy   -0.245 | reward +1779.9 |
# | timestep 114688 | policy   -3.325 | value   +3.521 | entropy   -0.261 | reward +1823.7 |
# | timestep 116736 | policy   -3.016 | value   +3.673 | entropy   -0.275 | reward +1886.4 |
# | timestep 118784 | policy   -4.537 | value   +2.751 | entropy   -0.294 | reward +1927.3 |
# | timestep 120832 | policy   -4.297 | value   +5.133 | entropy   -0.310 | reward +1987.3 |
# | timestep 122880 | policy   -4.177 | value   +3.137 | entropy   -0.323 | reward +2008.6 |
# | timestep 124928 | policy   -0.499 | value   +5.748 | entropy   -0.332 | reward +1938.9 |
# | timestep 126976 | policy   -4.931 | value   +3.177 | entropy   -0.340 | reward +1965.5 |
# | timestep 129024 | policy   -2.823 | value   +3.595 | entropy   -0.358 | reward +1943.0 |
# | timestep 131072 | policy   -0.312 | value   +5.868 | entropy   -0.365 | reward +1929.4 |
# | timestep 133120 | policy   -2.132 | value   +3.687 | entropy   -0.370 | reward +1935.8 |
# | timestep 135168 | policy   -3.576 | value   +2.600 | entropy   -0.385 | reward +1985.6 |
# | timestep 137216 | policy   -1.830 | value   +3.176 | entropy   -0.399 | reward +1974.8 |
# | timestep 139264 | policy   -2.436 | value   +3.278 | entropy   -0.406 | reward +2008.1 |
# | timestep 141312 | policy   -3.918 | value   +3.103 | entropy   -0.420 | reward +2045.8 |
# | timestep 143360 | policy   -5.037 | value   +3.380 | entropy   -0.443 | reward +2113.0 |
# | timestep 145408 | policy   -4.246 | value   +2.515 | entropy   -0.467 | reward +2153.2 |
# | timestep 147456 | policy   -3.954 | value   +2.651 | entropy   -0.488 | reward +2170.8 |
# | timestep 149504 | policy   -3.657 | value   +2.594 | entropy   -0.507 | reward +2146.9 |
# | timestep 151552 | policy   -2.267 | value   +3.771 | entropy   -0.522 | reward +2192.7 |
# | timestep 153600 | policy   -3.541 | value   +1.991 | entropy   -0.536 | reward +2225.4 |
# | timestep 155648 | policy   -1.990 | value   +3.472 | entropy   -0.550 | reward +2199.9 |
# | timestep 157696 | policy   -3.551 | value   +1.982 | entropy   -0.565 | reward +2240.2 |
# | timestep 159744 | policy   -0.849 | value   +3.254 | entropy   -0.580 | reward +2216.2 |
# | timestep 161792 | policy   -2.832 | value   +2.150 | entropy   -0.592 | reward +2300.0 |
# | timestep 163840 | policy   -1.948 | value   +2.105 | entropy   -0.606 | reward +2330.3 |
# | timestep 165888 | policy   -3.197 | value   +2.019 | entropy   -0.622 | reward +2370.3 |
# | timestep 167936 | policy   -3.008 | value   +1.547 | entropy   -0.642 | reward +2378.9 |
# | timestep 169984 | policy   -3.013 | value   +2.290 | entropy   -0.663 | reward +2428.8 |
# | timestep 172032 | policy   -1.291 | value   +2.914 | entropy   -0.675 | reward +2434.0 |
# | timestep 174080 | policy   -2.456 | value   +1.735 | entropy   -0.688 | reward +2465.6 |
# | timestep 176128 | policy   -3.352 | value   +1.915 | entropy   -0.710 | reward +2525.7 |
# | timestep 178176 | policy   -2.929 | value   +1.971 | entropy   -0.732 | reward +2565.3 |
# | timestep 180224 | policy   +2.084 | value   +6.350 | entropy   -0.738 | reward +2548.1 |
# | timestep 182272 | policy   -2.306 | value   +1.927 | entropy   -0.739 | reward +2540.4 |
# | timestep 184320 | policy   -2.526 | value   +1.646 | entropy   -0.756 | reward +2598.2 |
# | timestep 186368 | policy   -0.911 | value   +3.352 | entropy   -0.769 | reward +2646.9 |
# | timestep 188416 | policy   -1.840 | value   +2.979 | entropy   -0.778 | reward +2646.3 |
# | timestep 190464 | policy   +0.957 | value   +5.364 | entropy   -0.786 | reward +2590.3 |
# | timestep 192512 | policy   -2.503 | value   +2.123 | entropy   -0.794 | reward +2637.3 |
# | timestep 194560 | policy   -0.610 | value   +3.563 | entropy   -0.806 | reward +2626.0 |
# | timestep 196608 | policy   -0.271 | value   +3.532 | entropy   -0.808 | reward +2610.1 |
# | timestep 198656 | policy   +1.402 | value   +4.053 | entropy   -0.803 | reward +2628.1 |
# | timestep 200704 | policy   -1.403 | value   +1.538 | entropy   -0.804 | reward +2706.9 |
# | timestep 202752 | policy   -2.402 | value   +1.598 | entropy   -0.821 | reward +2787.3 |
# | timestep 204800 | policy   +1.315 | value   +4.677 | entropy   -0.831 | reward +2804.7 |
# | timestep 206848 | policy   -0.163 | value   +3.574 | entropy   -0.831 | reward +2851.3 |
# | timestep 208896 | policy   +3.287 | value   +6.592 | entropy   -0.824 | reward +2876.7 |
# | timestep 210944 | policy   -0.683 | value   +3.973 | entropy   -0.818 | reward +2907.4 |
# | timestep 212992 | policy   +0.190 | value   +3.436 | entropy   -0.817 | reward +2960.4 |
# | timestep 215040 | policy   -3.032 | value   +1.925 | entropy   -0.825 | reward +2937.9 |
# | timestep 217088 | policy   -1.709 | value   +2.731 | entropy   -0.842 | reward +2960.6 |
# | timestep 219136 | policy   +1.016 | value   +5.399 | entropy   -0.846 | reward +2986.6 |
# | timestep 221184 | policy   -0.541 | value   +2.900 | entropy   -0.844 | reward +3029.1 |
# | timestep 223232 | policy   +0.033 | value   +3.638 | entropy   -0.846 | reward +3031.7 |
# | timestep 225280 | policy   -0.200 | value   +3.861 | entropy   -0.848 | reward +3046.4 |
# | timestep 227328 | policy   -0.898 | value   +4.640 | entropy   -0.850 | reward +3045.4 |
# | timestep 229376 | policy   -1.358 | value   +2.107 | entropy   -0.856 | reward +3098.0 |
# | timestep 231424 | policy   +0.691 | value   +3.866 | entropy   -0.857 | reward +3138.1 |
# | timestep 233472 | policy   -1.809 | value   +1.683 | entropy   -0.862 | reward +3194.5 |
# | timestep 235520 | policy   +2.380 | value   +6.119 | entropy   -0.866 | reward +3180.2 |
# | timestep 237568 | policy   +2.625 | value   +6.326 | entropy   -0.854 | reward +3206.3 |
# | timestep 239616 | policy   +2.198 | value   +5.440 | entropy   -0.839 | reward +3204.8 |
# | timestep 241664 | policy   -0.420 | value   +3.740 | entropy   -0.832 | reward +3237.8 |
# | timestep 243712 | policy   +1.271 | value   +5.858 | entropy   -0.833 | reward +3240.7 |
# | timestep 245760 | policy   -1.724 | value   +1.853 | entropy   -0.840 | reward +3259.4 |
# | timestep 247808 | policy   +3.155 | value   +5.933 | entropy   -0.841 | reward +3265.8 |
# | timestep 249856 | policy   +3.539 | value   +6.516 | entropy   -0.825 | reward +3215.3 |
# | timestep 251904 | policy   +0.954 | value   +3.450 | entropy   -0.812 | reward +3222.5 |
# | timestep 253952 | policy   +4.537 | value   +7.103 | entropy   -0.801 | reward +3220.2 |
# | timestep 256000 | policy   -1.349 | value   +2.178 | entropy   -0.794 | reward +3267.1 |
# | timestep 258048 | policy   +1.319 | value   +4.484 | entropy   -0.795 | reward +3280.2 |
# | timestep 260096 | policy   +3.911 | value   +6.530 | entropy   -0.785 | reward +3300.5 |
# | timestep 262144 | policy   +1.616 | value   +4.314 | entropy   -0.775 | reward +3321.3 |
# | timestep 264192 | policy   +5.168 | value   +8.736 | entropy   -0.764 | reward +3303.2 |
# | timestep 266240 | policy   +6.223 | value   +8.097 | entropy   -0.747 | reward +3314.3 |
# | timestep 268288 | policy   +4.360 | value   +8.248 | entropy   -0.731 | reward +3294.1 |
# | timestep 270336 | policy   +6.022 | value   +9.275 | entropy   -0.720 | reward +3293.5 |
# | timestep 272384 | policy   +4.133 | value   +6.196 | entropy   -0.705 | reward +3395.1 |
# | timestep 274432 | policy   +4.082 | value   +6.370 | entropy   -0.690 | reward +3378.2 |
# | timestep 276480 | policy   +6.652 | value   +8.395 | entropy   -0.673 | reward +3326.9 |
# | timestep 278528 | policy   +4.093 | value   +6.099 | entropy   -0.657 | reward +3347.1 |
# | timestep 280576 | policy   +6.821 | value  +10.338 | entropy   -0.643 | reward +3353.7 |
# | timestep 282624 | policy   +1.711 | value   +5.355 | entropy   -0.631 | reward +3412.6 |
# | timestep 284672 | policy   +1.794 | value   +4.665 | entropy   -0.623 | reward +3415.0 |
# | timestep 286720 | policy   +4.725 | value   +6.101 | entropy   -0.610 | reward +3377.5 |
# | timestep 288768 | policy   +4.865 | value   +6.864 | entropy   -0.593 | reward +3370.1 |
# | timestep 290816 | policy   +7.000 | value   +9.052 | entropy   -0.574 | reward +3416.4 |
# | timestep 292864 | policy   +5.911 | value   +9.459 | entropy   -0.556 | reward +3442.6 |
# | timestep 294912 | policy   +5.624 | value  +10.543 | entropy   -0.543 | reward +3491.6 |
# | timestep 296960 | policy   +7.996 | value  +10.913 | entropy   -0.532 | reward +3449.1 |
# | timestep 299008 | policy   +9.220 | value  +10.811 | entropy   -0.517 | reward +3502.4 |
# | timestep 301056 | policy   +9.147 | value  +10.591 | entropy   -0.499 | reward +3464.9 |
# | timestep 303104 | policy   -0.440 | value   +4.052 | entropy   -0.490 | reward +3477.6 |
# | timestep 305152 | policy   +6.335 | value   +8.382 | entropy   -0.484 | reward +3487.5 |
# | timestep 307200 | policy   +7.679 | value   +9.303 | entropy   -0.465 | reward +3479.8 |
# | timestep 309248 | policy   +4.485 | value   +8.025 | entropy   -0.450 | reward +3526.8 |
# | timestep 311296 | policy   +8.614 | value  +10.215 | entropy   -0.437 | reward +3547.2 |
# | timestep 313344 | policy   +6.350 | value   +8.859 | entropy   -0.418 | reward +3535.8 |
# | timestep 315392 | policy  +10.289 | value  +12.916 | entropy   -0.400 | reward +3480.2 |
# | timestep 317440 | policy   +8.742 | value  +11.233 | entropy   -0.380 | reward +3464.9 |
# | timestep 319488 | policy  +11.878 | value  +14.877 | entropy   -0.357 | reward +3351.5 |
# | timestep 321536 | policy   +6.210 | value   +9.239 | entropy   -0.335 | reward +3407.6 |
# | timestep 323584 | policy  +13.646 | value  +14.762 | entropy   -0.316 | reward +3409.8 |
# | timestep 325632 | policy  +12.447 | value  +13.300 | entropy   -0.296 | reward +3456.7 |
# | timestep 327680 | policy   +6.503 | value  +10.785 | entropy   -0.279 | reward +3409.4 |
# | timestep 329728 | policy  +10.302 | value  +12.890 | entropy   -0.264 | reward +3439.7 |
# | timestep 331776 | policy  +15.847 | value  +16.649 | entropy   -0.245 | reward +3478.8 |
# | timestep 333824 | policy  +10.037 | value  +11.803 | entropy   -0.225 | reward +3515.2 |
# | timestep 335872 | policy  +15.106 | value  +15.527 | entropy   -0.205 | reward +3555.1 |
# | timestep 337920 | policy   +7.414 | value  +12.997 | entropy   -0.189 | reward +3583.5 |
# | timestep 339968 | policy  +14.628 | value  +14.726 | entropy   -0.169 | reward +3594.1 |
# | timestep 342016 | policy  +10.796 | value  +17.272 | entropy   -0.148 | reward +3611.8 |
# | timestep 344064 | policy   +9.665 | value  +16.232 | entropy   -0.137 | reward +3626.4 |
# | timestep 346112 | policy   +6.452 | value  +12.850 | entropy   -0.124 | reward +3592.0 |
# | timestep 348160 | policy   +8.683 | value  +13.589 | entropy   -0.111 | reward +3636.2 |
# | timestep 350208 | policy   +7.078 | value  +13.293 | entropy   -0.096 | reward +3623.2 |
# | timestep 352256 | policy   +6.602 | value  +13.891 | entropy   -0.086 | reward +3581.6 |
# | timestep 354304 | policy  +10.602 | value  +13.634 | entropy   -0.072 | reward +3550.7 |
# | timestep 356352 | policy   +6.761 | value  +11.521 | entropy   -0.053 | reward +3556.0 |
# | timestep 358400 | policy  +13.188 | value  +14.647 | entropy   -0.034 | reward +3529.7 |
# | timestep 360448 | policy  +10.925 | value  +14.540 | entropy   -0.013 | reward +3421.1 |
# | timestep 362496 | policy  +13.799 | value  +14.783 | entropy   +0.009 | reward +3322.6 |
# | timestep 364544 | policy   +4.294 | value  +10.955 | entropy   +0.026 | reward +3389.3 |
# | timestep 366592 | policy   +9.261 | value  +12.568 | entropy   +0.041 | reward +3398.2 |
# | timestep 368640 | policy  +10.925 | value  +16.032 | entropy   +0.063 | reward +3353.7 |
# | timestep 370688 | policy   +3.304 | value  +11.285 | entropy   +0.078 | reward +3325.2 |
# | timestep 372736 | policy   +8.544 | value  +15.392 | entropy   +0.089 | reward +3329.0 |
# | timestep 374784 | policy   +9.720 | value  +12.628 | entropy   +0.107 | reward +3237.2 |
# | timestep 376832 | policy   +6.891 | value  +12.381 | entropy   +0.126 | reward +3277.7 |
# | timestep 378880 | policy   +4.069 | value   +9.254 | entropy   +0.142 | reward +3311.9 |
# | timestep 380928 | policy   +5.800 | value  +14.178 | entropy   +0.154 | reward +3232.7 |
# | timestep 382976 | policy   +4.527 | value   +9.179 | entropy   +0.167 | reward +3280.4 |
# | timestep 385024 | policy   +7.661 | value  +12.746 | entropy   +0.185 | reward +3352.7 |
# | timestep 387072 | policy   +5.893 | value  +11.176 | entropy   +0.200 | reward +3277.6 |
# | timestep 389120 | policy   +4.983 | value  +12.522 | entropy   +0.212 | reward +3319.6 |
# | timestep 391168 | policy   +6.002 | value  +15.201 | entropy   +0.227 | reward +3249.1 |
# | timestep 393216 | policy   +7.318 | value  +14.596 | entropy   +0.244 | reward +3280.9 |
# | timestep 395264 | policy   +9.877 | value  +18.300 | entropy   +0.261 | reward +3185.3 |
# | timestep 397312 | policy   +8.555 | value  +16.472 | entropy   +0.281 | reward +3095.3 |
# | timestep 399360 | policy   +5.041 | value   +8.880 | entropy   +0.299 | reward +3160.2 |
# | timestep 401408 | policy   +5.742 | value  +12.515 | entropy   +0.313 | reward +2924.9 |
# | timestep 403456 | policy   +4.571 | value  +10.737 | entropy   +0.326 | reward +3134.8 |
# | timestep 405504 | policy   +3.882 | value  +13.698 | entropy   +0.339 | reward +2963.2 |
# | timestep 407552 | policy   +4.316 | value  +12.548 | entropy   +0.348 | reward +2796.4 |
# | timestep 409600 | policy   +7.582 | value  +13.256 | entropy   +0.363 | reward +3210.0 |
# | timestep 411648 | policy   +8.980 | value  +17.248 | entropy   +0.385 | reward +3210.6 |
# | timestep 413696 | policy   +2.520 | value  +10.284 | entropy   +0.399 | reward +3255.1 |
# | timestep 415744 | policy   +5.909 | value  +14.369 | entropy   +0.410 | reward +3238.1 |
# | timestep 417792 | policy   +6.847 | value  +13.303 | entropy   +0.426 | reward +3228.4 |
# | timestep 419840 | policy   +1.817 | value   +8.540 | entropy   +0.437 | reward +3211.6 |
# | timestep 421888 | policy   +6.533 | value  +10.932 | entropy   +0.451 | reward +2637.6 |
# | timestep 423936 | policy   +5.321 | value  +17.618 | entropy   +0.471 | reward +3198.9 |
# | timestep 425984 | policy   +4.038 | value  +12.050 | entropy   +0.483 | reward +3291.0 |
# | timestep 428032 | policy   +5.401 | value  +10.594 | entropy   +0.500 | reward +3240.3 |
# | timestep 430080 | policy   +5.402 | value  +12.018 | entropy   +0.515 | reward +3158.7 |
# | timestep 432128 | policy   +1.611 | value   +8.068 | entropy   +0.522 | reward +3225.0 |
# | timestep 434176 | policy   +2.729 | value   +8.413 | entropy   +0.528 | reward +2227.9 |
# | timestep 436224 | policy   +5.193 | value  +10.508 | entropy   +0.547 | reward +2446.6 |
# | timestep 438272 | policy   +8.808 | value  +15.439 | entropy   +0.567 | reward +2024.4 |
# | timestep 440320 | policy   +5.149 | value  +14.844 | entropy   +0.580 | reward +1661.6 |
# | timestep 442368 | policy   +7.118 | value  +12.113 | entropy   +0.593 | reward  +909.7 |
# | timestep 444416 | policy   +6.400 | value  +12.201 | entropy   +0.606 | reward +1044.7 |
# | timestep 446464 | policy   +4.273 | value  +10.940 | entropy   +0.617 | reward +2485.0 |
# | timestep 448512 | policy   +2.418 | value  +12.308 | entropy   +0.625 | reward +1706.1 |
# | timestep 450560 | policy   +4.343 | value  +12.088 | entropy   +0.629 | reward +1569.2 |
# | timestep 452608 | policy   +5.034 | value  +11.798 | entropy   +0.632 | reward +2647.9 |
# | timestep 454656 | policy   +3.686 | value  +12.381 | entropy   +0.637 | reward +2368.5 |
# | timestep 456704 | policy   +6.674 | value  +12.030 | entropy   +0.642 | reward +1819.2 |
# | timestep 458752 | policy   +3.376 | value   +9.959 | entropy   +0.647 | reward +2991.7 |
# | timestep 460800 | policy   +3.835 | value  +12.783 | entropy   +0.651 | reward +2645.8 |
# | timestep 462848 | policy   +3.210 | value  +12.543 | entropy   +0.654 | reward +1996.6 |
# | timestep 464896 | policy   +7.682 | value  +13.154 | entropy   +0.659 | reward +2366.4 |
# | timestep 466944 | policy   +5.881 | value  +17.120 | entropy   +0.665 | reward +1793.9 |
# | timestep 468992 | policy   +1.107 | value  +10.475 | entropy   +0.667 | reward +2069.1 |
# | timestep 471040 | policy   +4.449 | value  +11.152 | entropy   +0.669 | reward +2942.2 |
# | timestep 473088 | policy   +2.908 | value  +12.421 | entropy   +0.673 | reward +2328.1 |
# | timestep 475136 | policy   +2.452 | value  +15.570 | entropy   +0.676 | reward +2208.8 |
# | timestep 477184 | policy   -0.188 | value  +10.665 | entropy   +0.674 | reward +2363.8 |
# | timestep 479232 | policy   +3.298 | value  +11.546 | entropy   +0.677 | reward +2397.9 |
# | timestep 481280 | policy   +1.614 | value  +10.882 | entropy   +0.681 | reward +1965.3 |
# | timestep 483328 | policy   +2.944 | value  +16.249 | entropy   +0.682 | reward +1735.2 |
# | timestep 485376 | policy   +4.622 | value  +14.141 | entropy   +0.685 | reward +2043.7 |
# | timestep 487424 | policy   +2.870 | value  +11.529 | entropy   +0.685 | reward +2058.2 |
# | timestep 489472 | policy   +5.663 | value  +14.294 | entropy   +0.685 | reward +1181.1 |
# | timestep 491520 | policy   +3.560 | value  +12.056 | entropy   +0.688 | reward +2226.1 |
# | timestep 493568 | policy   +6.935 | value  +14.088 | entropy   +0.692 | reward  +566.7 |
# | timestep 495616 | policy   +2.417 | value  +10.489 | entropy   +0.695 | reward  +752.5 |
# | timestep 497664 | policy   +5.213 | value  +12.546 | entropy   +0.698 | reward +1428.7 |
# | timestep 499712 | policy   +5.645 | value  +12.805 | entropy   +0.701 | reward +1452.0 |

# %%
policy.load("./model_weights/HalfCheetah-v4")

# %%
env = gym.make('HalfCheetah-v4', render_mode=None)
mean, std = evaluate(policy, env, eval_num=32)
env.close()

print('mean : %f    std : %f'%(mean, std))
# Out:
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# mean : 3623.975342    std : 11.704700

# %%
env = gym.make('HalfCheetah-v4', render_mode='human')
evaluate(policy, env, eval_num=1, deterministic=True)
env.close()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
