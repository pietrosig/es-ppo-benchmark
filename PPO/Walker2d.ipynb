# %%
import torch.optim as optim
import gymnasium as gym

from simple_ppo import PPO
from simple_ppo.policy import ContinuMlpPolicy
from simple_ppo.utils import evaluate, plot

# %%
policy = ContinuMlpPolicy(state_dim=17, action_dim=6, sd_init=0.6, sd_rng=(0.01, 0.6))
optimizer = optim.Adam(policy.parameters(), lr=0.0001)

# %%
env = gym.make('Walker2d-v4', render_mode=None)
env_eval = gym.make('Walker2d-v4', render_mode=None)

agent = PPO(policy, optimizer, env, env_eval,
            gamma=0.99, gae_lambda=0.95, n_step=2048, batch_size=64, n_epochs=16,
            clip_eps=0.1, vf_coef=1.0, ent_coef=0.01, max_grad_norm=1.0,
            eval_num=4)

log = agent.train(total_timesteps=1500000)

env.close()
env_eval.close()
# Out:
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Walker2d-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Walker2d-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# | timestep   2048 | policy   -1.847 | value   +2.061 | entropy   +0.890 | reward   +17.4 |
# | timestep   4096 | policy   -3.583 | value   +3.158 | entropy   +0.855 | reward  +271.9 |
# | timestep   6144 | policy   -4.013 | value   +3.840 | entropy   +0.821 | reward  +330.7 |
# | timestep   8192 | policy   -5.024 | value   +6.049 | entropy   +0.793 | reward  +356.8 |
# | timestep  10240 | policy   -6.125 | value   +7.514 | entropy   +0.766 | reward  +321.5 |
# | timestep  12288 | policy   -3.884 | value   +7.563 | entropy   +0.744 | reward  +338.7 |
# | timestep  14336 | policy  -10.834 | value  +12.017 | entropy   +0.719 | reward  +351.4 |
# | timestep  16384 | policy   -4.542 | value   +8.528 | entropy   +0.696 | reward  +406.5 |
# | timestep  18432 | policy   -5.729 | value   +9.716 | entropy   +0.680 | reward  +351.4 |
# | timestep  20480 | policy   -5.800 | value  +10.186 | entropy   +0.665 | reward  +396.4 |
# | timestep  22528 | policy   -6.928 | value  +10.398 | entropy   +0.650 | reward  +314.6 |
# | timestep  24576 | policy  -11.569 | value  +12.625 | entropy   +0.628 | reward  +315.6 |
# | timestep  26624 | policy   -7.915 | value  +12.074 | entropy   +0.608 | reward  +371.5 |
# | timestep  28672 | policy   -8.279 | value  +12.216 | entropy   +0.592 | reward  +342.6 |
# | timestep  30720 | policy   -7.131 | value   +9.020 | entropy   +0.573 | reward  +301.1 |
# | timestep  32768 | policy  -10.502 | value  +10.483 | entropy   +0.551 | reward  +296.3 |
# | timestep  34816 | policy   -9.098 | value  +11.968 | entropy   +0.529 | reward  +288.7 |
# | timestep  36864 | policy   -8.684 | value  +13.337 | entropy   +0.515 | reward  +297.3 |
# | timestep  38912 | policy   -7.986 | value  +13.834 | entropy   +0.502 | reward  +285.8 |
# | timestep  40960 | policy   -4.806 | value  +11.984 | entropy   +0.493 | reward  +282.3 |
# | timestep  43008 | policy   -7.396 | value  +10.616 | entropy   +0.481 | reward  +282.4 |
# | timestep  45056 | policy   -6.974 | value  +10.597 | entropy   +0.467 | reward  +281.5 |
# | timestep  47104 | policy   -7.742 | value  +12.689 | entropy   +0.457 | reward  +285.5 |
# | timestep  49152 | policy   -6.472 | value  +10.073 | entropy   +0.447 | reward  +284.4 |
# | timestep  51200 | policy   -7.318 | value  +12.473 | entropy   +0.437 | reward  +298.0 |
# | timestep  53248 | policy   -6.840 | value  +11.007 | entropy   +0.426 | reward  +281.7 |
# | timestep  55296 | policy   -5.943 | value   +9.292 | entropy   +0.414 | reward  +272.3 |
# | timestep  57344 | policy   -4.542 | value  +11.584 | entropy   +0.405 | reward  +269.3 |
# | timestep  59392 | policy   -3.328 | value  +11.357 | entropy   +0.400 | reward  +267.5 |
# | timestep  61440 | policy   -3.129 | value  +11.059 | entropy   +0.397 | reward  +262.6 |
# | timestep  63488 | policy   -3.717 | value  +10.152 | entropy   +0.396 | reward  +268.3 |
# | timestep  65536 | policy   -1.879 | value  +10.843 | entropy   +0.394 | reward  +267.0 |
# | timestep  67584 | policy   -1.898 | value  +10.457 | entropy   +0.391 | reward  +270.4 |
# | timestep  69632 | policy   -0.329 | value  +11.514 | entropy   +0.392 | reward  +265.5 |
# | timestep  71680 | policy   -0.641 | value  +11.024 | entropy   +0.396 | reward  +267.0 |
# | timestep  73728 | policy   +0.967 | value  +11.502 | entropy   +0.402 | reward  +266.3 |
# | timestep  75776 | policy   -0.117 | value  +10.787 | entropy   +0.405 | reward  +265.9 |
# | timestep  77824 | policy   +0.999 | value  +11.417 | entropy   +0.409 | reward  +265.2 |
# | timestep  79872 | policy   +0.887 | value   +9.202 | entropy   +0.412 | reward  +267.4 |
# | timestep  81920 | policy   +0.013 | value  +10.208 | entropy   +0.415 | reward  +274.9 |
# | timestep  83968 | policy   +1.967 | value  +10.882 | entropy   +0.418 | reward  +278.8 |
# | timestep  86016 | policy   +1.748 | value   +9.728 | entropy   +0.422 | reward  +280.3 |
# | timestep  88064 | policy   +2.434 | value  +10.232 | entropy   +0.429 | reward  +279.4 |
# | timestep  90112 | policy   +2.698 | value   +9.806 | entropy   +0.439 | reward  +278.9 |
# | timestep  92160 | policy   +4.191 | value  +10.972 | entropy   +0.450 | reward  +275.1 |
# | timestep  94208 | policy   +3.878 | value  +11.141 | entropy   +0.461 | reward  +278.2 |
# | timestep  96256 | policy   +4.308 | value  +11.434 | entropy   +0.473 | reward  +273.4 |
# | timestep  98304 | policy   +6.577 | value  +11.928 | entropy   +0.483 | reward  +274.7 |
# | timestep 100352 | policy   +6.575 | value  +12.496 | entropy   +0.497 | reward  +269.1 |
# | timestep 102400 | policy   +5.569 | value  +11.185 | entropy   +0.508 | reward  +273.5 |
# | timestep 104448 | policy   +6.153 | value  +11.557 | entropy   +0.525 | reward  +267.3 |
# | timestep 106496 | policy   +5.912 | value  +11.027 | entropy   +0.543 | reward  +270.8 |
# | timestep 108544 | policy   +6.754 | value  +11.641 | entropy   +0.556 | reward  +267.7 |
# | timestep 110592 | policy   +5.998 | value  +10.671 | entropy   +0.569 | reward  +264.9 |
# | timestep 112640 | policy   +5.988 | value  +13.830 | entropy   +0.580 | reward  +266.5 |
# | timestep 114688 | policy   +8.079 | value  +12.545 | entropy   +0.594 | reward  +265.7 |
# | timestep 116736 | policy   +5.029 | value  +13.911 | entropy   +0.605 | reward  +264.1 |
# | timestep 118784 | policy   +6.815 | value  +12.859 | entropy   +0.616 | reward  +268.8 |
# | timestep 120832 | policy   +7.483 | value  +12.205 | entropy   +0.634 | reward  +266.7 |
# | timestep 122880 | policy   +8.550 | value  +12.885 | entropy   +0.651 | reward  +284.5 |
# | timestep 124928 | policy   +6.571 | value  +11.102 | entropy   +0.667 | reward  +288.4 |
# | timestep 126976 | policy  +10.395 | value  +15.617 | entropy   +0.685 | reward  +285.7 |
# | timestep 129024 | policy   +7.709 | value  +11.833 | entropy   +0.710 | reward  +279.0 |
# | timestep 131072 | policy   +8.151 | value  +11.922 | entropy   +0.736 | reward  +275.0 |
# | timestep 133120 | policy   +9.425 | value  +13.305 | entropy   +0.756 | reward  +281.1 |
# | timestep 135168 | policy   +5.103 | value  +13.032 | entropy   +0.770 | reward  +272.6 |
# | timestep 137216 | policy   +7.746 | value  +12.903 | entropy   +0.784 | reward  +276.2 |
# | timestep 139264 | policy   +7.557 | value  +12.783 | entropy   +0.802 | reward  +275.8 |
# | timestep 141312 | policy   +7.396 | value  +13.504 | entropy   +0.817 | reward  +276.0 |
# | timestep 143360 | policy   +7.894 | value  +15.097 | entropy   +0.833 | reward  +271.4 |
# | timestep 145408 | policy   +9.070 | value  +13.404 | entropy   +0.848 | reward  +287.7 |
# | timestep 147456 | policy   +6.575 | value  +11.757 | entropy   +0.857 | reward  +276.5 |
# | timestep 149504 | policy   +6.538 | value  +10.803 | entropy   +0.863 | reward  +282.0 |
# | timestep 151552 | policy   +7.368 | value  +13.399 | entropy   +0.870 | reward  +276.1 |
# | timestep 153600 | policy   +6.767 | value  +12.068 | entropy   +0.877 | reward  +277.7 |
# | timestep 155648 | policy   +6.740 | value  +12.094 | entropy   +0.884 | reward  +280.0 |
# | timestep 157696 | policy   +8.077 | value  +13.605 | entropy   +0.893 | reward  +286.1 |
# | timestep 159744 | policy   +6.957 | value  +13.125 | entropy   +0.903 | reward  +286.2 |
# | timestep 161792 | policy   +6.208 | value  +11.416 | entropy   +0.908 | reward  +310.5 |
# | timestep 163840 | policy   +7.928 | value  +11.780 | entropy   +0.908 | reward  +311.3 |
# | timestep 165888 | policy   +8.135 | value  +12.509 | entropy   +0.908 | reward  +310.6 |
# | timestep 167936 | policy   +7.555 | value  +14.010 | entropy   +0.908 | reward  +311.1 |
# | timestep 169984 | policy   +8.008 | value  +11.574 | entropy   +0.908 | reward  +311.7 |
# | timestep 172032 | policy   +8.021 | value  +11.918 | entropy   +0.908 | reward  +329.3 |
# | timestep 174080 | policy   +7.608 | value  +11.381 | entropy   +0.908 | reward  +355.4 |
# | timestep 176128 | policy   +8.196 | value  +12.342 | entropy   +0.908 | reward  +364.8 |
# | timestep 178176 | policy   +9.058 | value  +12.594 | entropy   +0.908 | reward  +354.2 |
# | timestep 180224 | policy   +9.534 | value  +11.607 | entropy   +0.908 | reward  +362.5 |
# | timestep 182272 | policy   +9.282 | value  +13.941 | entropy   +0.908 | reward  +380.4 |
# | timestep 184320 | policy   +8.380 | value  +13.885 | entropy   +0.908 | reward  +381.0 |
# | timestep 186368 | policy   +8.097 | value  +11.621 | entropy   +0.908 | reward  +364.2 |
# | timestep 188416 | policy   +8.197 | value  +14.698 | entropy   +0.908 | reward  +372.2 |
# | timestep 190464 | policy   +7.970 | value  +11.492 | entropy   +0.908 | reward  +366.7 |
# | timestep 192512 | policy   +8.623 | value  +12.811 | entropy   +0.908 | reward  +383.2 |
# | timestep 194560 | policy   +9.794 | value  +13.757 | entropy   +0.908 | reward  +386.6 |
# | timestep 196608 | policy   +8.607 | value   +9.852 | entropy   +0.908 | reward  +390.5 |
# | timestep 198656 | policy   +7.753 | value   +5.513 | entropy   +0.908 | reward  +414.4 |
# | timestep 200704 | policy   +6.170 | value   +6.124 | entropy   +0.908 | reward  +422.0 |
# | timestep 202752 | policy   +4.983 | value   +4.922 | entropy   +0.908 | reward  +420.9 |
# | timestep 204800 | policy   +4.273 | value   +5.407 | entropy   +0.908 | reward  +435.6 |
# | timestep 206848 | policy   +4.340 | value   +4.794 | entropy   +0.908 | reward  +443.2 |
# | timestep 208896 | policy   +2.856 | value   +3.656 | entropy   +0.908 | reward  +445.3 |
# | timestep 210944 | policy   +1.904 | value   +3.375 | entropy   +0.908 | reward  +451.5 |
# | timestep 212992 | policy   +1.820 | value   +3.276 | entropy   +0.908 | reward  +445.4 |
# | timestep 215040 | policy   +4.639 | value   +3.329 | entropy   +0.908 | reward  +455.5 |
# | timestep 217088 | policy   +1.844 | value   +3.032 | entropy   +0.908 | reward  +455.1 |
# | timestep 219136 | policy   +1.863 | value   +3.188 | entropy   +0.908 | reward  +456.9 |
# | timestep 221184 | policy   +0.962 | value   +3.601 | entropy   +0.908 | reward  +476.0 |
# | timestep 223232 | policy   +0.107 | value   +3.364 | entropy   +0.907 | reward  +466.2 |
# | timestep 225280 | policy   +0.335 | value   +3.640 | entropy   +0.906 | reward  +442.5 |
# | timestep 227328 | policy   -0.089 | value   +3.768 | entropy   +0.904 | reward  +454.7 |
# | timestep 229376 | policy   -0.310 | value   +3.429 | entropy   +0.898 | reward  +484.7 |
# | timestep 231424 | policy   -0.057 | value   +2.952 | entropy   +0.889 | reward  +497.9 |
# | timestep 233472 | policy   +1.737 | value   +3.399 | entropy   +0.895 | reward  +512.7 |
# | timestep 235520 | policy   -0.127 | value   +3.945 | entropy   +0.899 | reward  +501.5 |
# | timestep 237568 | policy   -0.434 | value   +4.115 | entropy   +0.890 | reward  +518.3 |
# | timestep 239616 | policy   +0.396 | value   +3.225 | entropy   +0.887 | reward  +548.3 |
# | timestep 241664 | policy   +0.001 | value   +2.254 | entropy   +0.887 | reward  +538.4 |
# | timestep 243712 | policy   +0.031 | value   +2.479 | entropy   +0.883 | reward  +562.7 |
# | timestep 245760 | policy   +1.088 | value   +3.102 | entropy   +0.891 | reward  +611.5 |
# | timestep 247808 | policy   +1.190 | value   +2.792 | entropy   +0.901 | reward  +571.9 |
# | timestep 249856 | policy   +0.739 | value   +2.939 | entropy   +0.904 | reward  +583.8 |
# | timestep 251904 | policy   +1.716 | value   +3.424 | entropy   +0.907 | reward  +667.4 |
# | timestep 253952 | policy   +1.572 | value   +2.784 | entropy   +0.908 | reward  +577.0 |
# | timestep 256000 | policy   +0.194 | value   +3.083 | entropy   +0.908 | reward  +619.8 |
# | timestep 258048 | policy   -0.510 | value   +2.172 | entropy   +0.898 | reward  +573.7 |
# | timestep 260096 | policy   +1.447 | value   +2.440 | entropy   +0.899 | reward  +539.3 |
# | timestep 262144 | policy   +1.126 | value   +2.476 | entropy   +0.908 | reward  +541.4 |
# | timestep 264192 | policy   +0.239 | value   +2.695 | entropy   +0.907 | reward  +576.7 |
# | timestep 266240 | policy   +0.138 | value   +1.945 | entropy   +0.905 | reward  +552.2 |
# | timestep 268288 | policy   +0.543 | value   +1.984 | entropy   +0.908 | reward  +588.9 |
# | timestep 270336 | policy   +0.091 | value   +1.911 | entropy   +0.908 | reward  +585.1 |
# | timestep 272384 | policy   -0.382 | value   +2.428 | entropy   +0.903 | reward  +543.4 |
# | timestep 274432 | policy   +0.572 | value   +2.013 | entropy   +0.904 | reward  +530.6 |
# | timestep 276480 | policy   +1.230 | value   +2.536 | entropy   +0.908 | reward  +519.5 |
# | timestep 278528 | policy   +0.540 | value   +2.480 | entropy   +0.908 | reward  +485.6 |
# | timestep 280576 | policy   +0.590 | value   +2.120 | entropy   +0.908 | reward  +513.9 |
# | timestep 282624 | policy   +0.727 | value   +2.232 | entropy   +0.908 | reward  +483.8 |
# | timestep 284672 | policy   +0.085 | value   +2.452 | entropy   +0.907 | reward  +495.9 |
# | timestep 286720 | policy   -0.253 | value   +2.117 | entropy   +0.901 | reward  +466.3 |
# | timestep 288768 | policy   +0.677 | value   +2.853 | entropy   +0.901 | reward  +498.7 |
# | timestep 290816 | policy   +1.453 | value   +2.254 | entropy   +0.908 | reward  +456.8 |
# | timestep 292864 | policy   -1.073 | value   +2.048 | entropy   +0.894 | reward  +505.8 |
# | timestep 294912 | policy   -0.137 | value   +2.636 | entropy   +0.875 | reward  +507.6 |
# | timestep 296960 | policy   +0.079 | value   +2.534 | entropy   +0.868 | reward  +455.9 |
# | timestep 299008 | policy   -0.641 | value   +2.076 | entropy   +0.856 | reward  +453.1 |
# | timestep 301056 | policy   +0.570 | value   +2.083 | entropy   +0.854 | reward  +445.9 |
# | timestep 303104 | policy   -0.158 | value   +2.627 | entropy   +0.860 | reward  +476.2 |
# | timestep 305152 | policy   +0.498 | value   +2.028 | entropy   +0.865 | reward  +469.6 |
# | timestep 307200 | policy   -0.217 | value   +2.489 | entropy   +0.869 | reward  +450.5 |
# | timestep 309248 | policy   +0.442 | value   +2.097 | entropy   +0.873 | reward  +440.0 |
# | timestep 311296 | policy   +0.610 | value   +2.480 | entropy   +0.886 | reward  +385.6 |
# | timestep 313344 | policy   +0.927 | value   +2.408 | entropy   +0.898 | reward  +392.3 |
# | timestep 315392 | policy   -0.830 | value   +2.183 | entropy   +0.891 | reward  +411.4 |
# | timestep 317440 | policy   +0.742 | value   +2.540 | entropy   +0.886 | reward  +373.9 |
# | timestep 319488 | policy   -0.508 | value   +3.451 | entropy   +0.887 | reward  +405.9 |
# | timestep 321536 | policy   -0.053 | value   +2.482 | entropy   +0.878 | reward  +380.9 |
# | timestep 323584 | policy   -0.403 | value   +2.137 | entropy   +0.866 | reward  +382.8 |
# | timestep 325632 | policy   +0.488 | value   +2.769 | entropy   +0.862 | reward  +398.6 |
# | timestep 327680 | policy   -0.143 | value   +2.230 | entropy   +0.864 | reward  +368.3 |
# | timestep 329728 | policy   +0.829 | value   +2.915 | entropy   +0.870 | reward  +366.1 |
# | timestep 331776 | policy   +0.354 | value   +2.475 | entropy   +0.883 | reward  +367.6 |
# | timestep 333824 | policy   +0.359 | value   +2.928 | entropy   +0.888 | reward  +375.3 |
# | timestep 335872 | policy   +0.664 | value   +2.446 | entropy   +0.894 | reward  +364.3 |
# | timestep 337920 | policy   -0.208 | value   +2.611 | entropy   +0.893 | reward  +354.5 |
# | timestep 339968 | policy   -0.475 | value   +1.878 | entropy   +0.880 | reward  +376.0 |
# | timestep 342016 | policy   +0.272 | value   +2.238 | entropy   +0.875 | reward  +357.8 |
# | timestep 344064 | policy   +1.077 | value   +2.938 | entropy   +0.886 | reward  +370.6 |
# | timestep 346112 | policy   -0.039 | value   +2.567 | entropy   +0.889 | reward  +373.0 |
# | timestep 348160 | policy   +0.931 | value   +2.716 | entropy   +0.892 | reward  +370.8 |
# | timestep 350208 | policy   -0.372 | value   +2.760 | entropy   +0.889 | reward  +374.1 |
# | timestep 352256 | policy   +0.577 | value   +2.548 | entropy   +0.887 | reward  +386.1 |
# | timestep 354304 | policy   +1.331 | value   +2.474 | entropy   +0.900 | reward  +405.2 |
# | timestep 356352 | policy   -0.618 | value   +2.926 | entropy   +0.894 | reward  +375.5 |
# | timestep 358400 | policy   -0.732 | value   +2.130 | entropy   +0.873 | reward  +377.9 |
# | timestep 360448 | policy   +0.488 | value   +2.020 | entropy   +0.866 | reward  +371.4 |
# | timestep 362496 | policy   +1.068 | value   +2.895 | entropy   +0.885 | reward  +358.5 |
# | timestep 364544 | policy   -0.654 | value   +1.916 | entropy   +0.885 | reward  +380.2 |
# | timestep 366592 | policy   +0.398 | value   +2.030 | entropy   +0.878 | reward  +372.7 |
# | timestep 368640 | policy   -0.760 | value   +2.108 | entropy   +0.874 | reward  +373.4 |
# | timestep 370688 | policy   +0.808 | value   +2.030 | entropy   +0.874 | reward  +361.5 |
# | timestep 372736 | policy   +0.419 | value   +1.999 | entropy   +0.887 | reward  +364.7 |
# | timestep 374784 | policy   +1.004 | value   +2.260 | entropy   +0.895 | reward  +358.3 |
# | timestep 376832 | policy   +0.352 | value   +2.214 | entropy   +0.898 | reward  +352.7 |
# | timestep 378880 | policy   -0.510 | value   +2.144 | entropy   +0.889 | reward  +377.7 |
# | timestep 380928 | policy   +0.711 | value   +2.475 | entropy   +0.887 | reward  +387.7 |
# | timestep 382976 | policy   +1.312 | value   +2.597 | entropy   +0.900 | reward  +373.1 |
# | timestep 385024 | policy   -0.021 | value   +1.729 | entropy   +0.902 | reward  +365.2 |
# | timestep 387072 | policy   -0.107 | value   +2.190 | entropy   +0.898 | reward  +361.3 |
# | timestep 389120 | policy   -0.663 | value   +1.925 | entropy   +0.886 | reward  +369.7 |
# | timestep 391168 | policy   -0.466 | value   +1.908 | entropy   +0.866 | reward  +374.3 |
# | timestep 393216 | policy   -0.150 | value   +2.022 | entropy   +0.852 | reward  +361.2 |
# | timestep 395264 | policy   -0.971 | value   +2.053 | entropy   +0.834 | reward  +361.3 |
# | timestep 397312 | policy   +1.868 | value   +2.808 | entropy   +0.839 | reward  +376.4 |
# | timestep 399360 | policy   -0.196 | value   +2.266 | entropy   +0.851 | reward  +354.0 |
# | timestep 401408 | policy   +0.597 | value   +2.750 | entropy   +0.849 | reward  +369.7 |
# | timestep 403456 | policy   +0.709 | value   +2.503 | entropy   +0.861 | reward  +366.5 |
# | timestep 405504 | policy   -1.676 | value   +2.039 | entropy   +0.849 | reward  +359.8 |
# | timestep 407552 | policy   -0.168 | value   +1.682 | entropy   +0.825 | reward  +362.0 |
# | timestep 409600 | policy   +0.873 | value   +2.135 | entropy   +0.836 | reward  +374.9 |
# | timestep 411648 | policy   +0.726 | value   +2.251 | entropy   +0.857 | reward  +378.2 |
# | timestep 413696 | policy   +0.379 | value   +1.628 | entropy   +0.871 | reward  +394.8 |
# | timestep 415744 | policy   -1.030 | value   +1.925 | entropy   +0.860 | reward  +381.4 |
# | timestep 417792 | policy   +0.045 | value   +2.030 | entropy   +0.842 | reward  +368.3 |
# | timestep 419840 | policy   -1.378 | value   +1.835 | entropy   +0.819 | reward  +394.0 |
# | timestep 421888 | policy   -0.758 | value   +1.912 | entropy   +0.784 | reward  +405.1 |
# | timestep 423936 | policy   +0.045 | value   +2.276 | entropy   +0.766 | reward  +418.3 |
# | timestep 425984 | policy   -0.437 | value   +1.851 | entropy   +0.754 | reward  +403.9 |
# | timestep 428032 | policy   -0.674 | value   +1.888 | entropy   +0.734 | reward  +383.1 |
# | timestep 430080 | policy   -1.061 | value   +1.945 | entropy   +0.706 | reward  +395.2 |
# | timestep 432128 | policy   -0.662 | value   +1.649 | entropy   +0.679 | reward  +393.9 |
# | timestep 434176 | policy   +0.984 | value   +2.253 | entropy   +0.679 | reward  +393.6 |
# | timestep 436224 | policy   -0.497 | value   +1.907 | entropy   +0.683 | reward  +391.7 |
# | timestep 438272 | policy   +1.068 | value   +2.342 | entropy   +0.685 | reward  +399.2 |
# | timestep 440320 | policy   -0.515 | value   +2.092 | entropy   +0.688 | reward  +387.2 |
# | timestep 442368 | policy   +0.692 | value   +1.759 | entropy   +0.688 | reward  +398.6 |
# | timestep 444416 | policy   +0.015 | value   +2.085 | entropy   +0.698 | reward  +398.1 |
# | timestep 446464 | policy   +0.658 | value   +2.308 | entropy   +0.707 | reward  +389.0 |
# | timestep 448512 | policy   -0.230 | value   +2.132 | entropy   +0.711 | reward  +404.2 |
# | timestep 450560 | policy   -0.432 | value   +2.120 | entropy   +0.698 | reward  +388.9 |
# | timestep 452608 | policy   -0.044 | value   +2.152 | entropy   +0.687 | reward  +392.0 |
# | timestep 454656 | policy   +0.174 | value   +2.343 | entropy   +0.685 | reward  +392.4 |
# | timestep 456704 | policy   -0.031 | value   +1.648 | entropy   +0.681 | reward  +395.9 |
# | timestep 458752 | policy   -0.016 | value   +2.108 | entropy   +0.674 | reward  +401.2 |
# | timestep 460800 | policy   -0.207 | value   +1.925 | entropy   +0.667 | reward  +417.3 |
# | timestep 462848 | policy   -0.107 | value   +1.973 | entropy   +0.660 | reward  +408.5 |
# | timestep 464896 | policy   +0.296 | value   +2.030 | entropy   +0.660 | reward  +418.7 |
# | timestep 466944 | policy   -1.130 | value   +1.390 | entropy   +0.646 | reward  +427.1 |
# | timestep 468992 | policy   -0.095 | value   +1.973 | entropy   +0.624 | reward  +430.4 |
# | timestep 471040 | policy   +0.455 | value   +2.235 | entropy   +0.624 | reward  +433.0 |
# | timestep 473088 | policy   -0.575 | value   +1.345 | entropy   +0.617 | reward  +450.0 |
# | timestep 475136 | policy   -0.657 | value   +1.514 | entropy   +0.594 | reward  +464.2 |
# | timestep 477184 | policy   -0.700 | value   +1.444 | entropy   +0.571 | reward  +467.9 |
# | timestep 479232 | policy   -0.512 | value   +1.618 | entropy   +0.550 | reward  +464.6 |
# | timestep 481280 | policy   -0.094 | value   +1.812 | entropy   +0.538 | reward  +474.3 |
# | timestep 483328 | policy   -0.251 | value   +1.479 | entropy   +0.532 | reward  +474.4 |
# | timestep 485376 | policy   +1.567 | value   +2.394 | entropy   +0.544 | reward  +474.3 |
# | timestep 487424 | policy   -0.545 | value   +1.396 | entropy   +0.551 | reward  +479.1 |
# | timestep 489472 | policy   -0.819 | value   +1.230 | entropy   +0.530 | reward  +476.6 |
# | timestep 491520 | policy   -0.290 | value   +1.562 | entropy   +0.512 | reward  +468.2 |
# | timestep 493568 | policy   -0.650 | value   +1.457 | entropy   +0.496 | reward  +467.4 |
# | timestep 495616 | policy   -0.587 | value   +1.588 | entropy   +0.477 | reward  +467.7 |
# | timestep 497664 | policy   -0.207 | value   +1.497 | entropy   +0.460 | reward  +471.6 |
# | timestep 499712 | policy   -0.233 | value   +1.279 | entropy   +0.451 | reward  +473.4 |
# | timestep 501760 | policy   -1.294 | value   +1.170 | entropy   +0.422 | reward  +478.9 |
# | timestep 503808 | policy   +0.076 | value   +1.374 | entropy   +0.398 | reward  +486.1 |
# | timestep 505856 | policy   -0.518 | value   +1.186 | entropy   +0.388 | reward  +481.9 |
# | timestep 507904 | policy   -1.107 | value   +1.158 | entropy   +0.359 | reward  +487.5 |
# | timestep 509952 | policy   -0.030 | value   +1.372 | entropy   +0.341 | reward  +483.9 |
# | timestep 512000 | policy   -0.120 | value   +1.183 | entropy   +0.338 | reward  +490.6 |
# | timestep 514048 | policy   -0.541 | value   +1.286 | entropy   +0.327 | reward  +494.1 |
# | timestep 516096 | policy   -0.578 | value   +1.300 | entropy   +0.306 | reward  +493.6 |
# | timestep 518144 | policy   -0.274 | value   +1.112 | entropy   +0.286 | reward  +487.1 |
# | timestep 520192 | policy   -0.296 | value   +1.026 | entropy   +0.272 | reward  +504.5 |
# | timestep 522240 | policy   -0.862 | value   +1.107 | entropy   +0.251 | reward  +503.2 |
# | timestep 524288 | policy   +0.225 | value   +1.156 | entropy   +0.238 | reward  +505.8 |
# | timestep 526336 | policy   -0.454 | value   +0.788 | entropy   +0.235 | reward  +503.6 |
# | timestep 528384 | policy   +0.139 | value   +1.197 | entropy   +0.229 | reward  +516.2 |
# | timestep 530432 | policy   +0.557 | value   +1.381 | entropy   +0.239 | reward  +518.2 |
# | timestep 532480 | policy   +0.135 | value   +1.714 | entropy   +0.251 | reward  +509.7 |
# | timestep 534528 | policy   +0.243 | value   +1.398 | entropy   +0.261 | reward  +515.0 |
# | timestep 536576 | policy   +0.306 | value   +1.280 | entropy   +0.271 | reward  +514.8 |
# | timestep 538624 | policy   -0.016 | value   +0.986 | entropy   +0.276 | reward  +523.8 |
# | timestep 540672 | policy   +0.251 | value   +1.336 | entropy   +0.278 | reward  +526.2 |
# | timestep 542720 | policy   +0.069 | value   +1.018 | entropy   +0.283 | reward  +527.4 |
# | timestep 544768 | policy   -0.489 | value   +1.251 | entropy   +0.274 | reward  +517.0 |
# | timestep 546816 | policy   -0.403 | value   +1.225 | entropy   +0.254 | reward  +514.6 |
# | timestep 548864 | policy   -0.281 | value   +1.224 | entropy   +0.240 | reward  +528.1 |
# | timestep 550912 | policy   +0.301 | value   +1.053 | entropy   +0.245 | reward  +524.1 |
# | timestep 552960 | policy   +0.168 | value   +1.646 | entropy   +0.256 | reward  +533.1 |
# | timestep 555008 | policy   -0.451 | value   +1.072 | entropy   +0.249 | reward  +550.1 |
# | timestep 557056 | policy   -0.134 | value   +1.057 | entropy   +0.236 | reward  +541.0 |
# | timestep 559104 | policy   -0.048 | value   +1.223 | entropy   +0.231 | reward  +545.6 |
# | timestep 561152 | policy   +0.146 | value   +1.485 | entropy   +0.230 | reward  +538.2 |
# | timestep 563200 | policy   -0.403 | value   +0.946 | entropy   +0.222 | reward  +537.8 |
# | timestep 565248 | policy   -0.040 | value   +1.021 | entropy   +0.210 | reward  +545.4 |
# | timestep 567296 | policy   +0.162 | value   +1.110 | entropy   +0.209 | reward  +546.1 |
# | timestep 569344 | policy   +0.049 | value   +0.986 | entropy   +0.212 | reward  +538.1 |
# | timestep 571392 | policy   +0.563 | value   +1.451 | entropy   +0.225 | reward  +548.7 |
# | timestep 573440 | policy   -0.219 | value   +0.985 | entropy   +0.232 | reward  +538.5 |
# | timestep 575488 | policy   -0.087 | value   +1.202 | entropy   +0.227 | reward  +549.3 |
# | timestep 577536 | policy   -0.529 | value   +1.078 | entropy   +0.214 | reward  +550.4 |
# | timestep 579584 | policy   -0.326 | value   +1.003 | entropy   +0.196 | reward  +556.4 |
# | timestep 581632 | policy   -0.085 | value   +1.121 | entropy   +0.189 | reward  +550.8 |
# | timestep 583680 | policy   +0.019 | value   +1.428 | entropy   +0.189 | reward  +570.6 |
# | timestep 585728 | policy   +0.130 | value   +1.051 | entropy   +0.188 | reward  +560.2 |
# | timestep 587776 | policy   -0.178 | value   +1.043 | entropy   +0.182 | reward  +561.3 |
# | timestep 589824 | policy   +0.162 | value   +1.490 | entropy   +0.176 | reward  +545.6 |
# | timestep 591872 | policy   -0.241 | value   +1.085 | entropy   +0.171 | reward  +553.1 |
# | timestep 593920 | policy   -0.335 | value   +0.963 | entropy   +0.160 | reward  +554.8 |
# | timestep 595968 | policy   -0.238 | value   +1.023 | entropy   +0.148 | reward  +542.4 |
# | timestep 598016 | policy   +0.687 | value   +1.355 | entropy   +0.156 | reward  +569.5 |
# | timestep 600064 | policy   +0.441 | value   +1.771 | entropy   +0.172 | reward  +566.5 |
# | timestep 602112 | policy   +0.759 | value   +1.600 | entropy   +0.191 | reward  +573.4 |
# | timestep 604160 | policy   +0.206 | value   +1.345 | entropy   +0.206 | reward  +574.1 |
# | timestep 606208 | policy   +0.179 | value   +1.704 | entropy   +0.209 | reward  +573.5 |
# | timestep 608256 | policy   -0.867 | value   +0.833 | entropy   +0.191 | reward  +574.3 |
# | timestep 610304 | policy   +0.145 | value   +1.023 | entropy   +0.175 | reward  +549.2 |
# | timestep 612352 | policy   +0.013 | value   +1.241 | entropy   +0.177 | reward  +560.9 |
# | timestep 614400 | policy   +0.627 | value   +1.885 | entropy   +0.183 | reward  +580.8 |
# | timestep 616448 | policy   +0.296 | value   +1.895 | entropy   +0.193 | reward  +580.3 |
# | timestep 618496 | policy   -0.119 | value   +1.119 | entropy   +0.196 | reward  +561.4 |
# | timestep 620544 | policy   -0.205 | value   +1.160 | entropy   +0.189 | reward  +574.3 |
# | timestep 622592 | policy   +0.393 | value   +1.060 | entropy   +0.192 | reward  +576.5 |
# | timestep 624640 | policy   -0.007 | value   +1.229 | entropy   +0.197 | reward  +573.8 |
# | timestep 626688 | policy   -0.093 | value   +1.543 | entropy   +0.192 | reward  +584.4 |
# | timestep 628736 | policy   +0.319 | value   +1.287 | entropy   +0.196 | reward  +584.8 |
# | timestep 630784 | policy   +0.268 | value   +1.355 | entropy   +0.206 | reward  +593.7 |
# | timestep 632832 | policy   +1.645 | value   +2.181 | entropy   +0.228 | reward  +596.9 |
# | timestep 634880 | policy   +0.972 | value   +1.479 | entropy   +0.258 | reward  +577.7 |
# | timestep 636928 | policy   +0.267 | value   +1.560 | entropy   +0.274 | reward  +598.3 |
# | timestep 638976 | policy   +1.051 | value   +2.136 | entropy   +0.291 | reward  +577.5 |
# | timestep 641024 | policy   +0.965 | value   +2.290 | entropy   +0.315 | reward  +581.4 |
# | timestep 643072 | policy   +0.879 | value   +2.149 | entropy   +0.334 | reward  +543.0 |
# | timestep 645120 | policy   +1.195 | value   +1.958 | entropy   +0.356 | reward  +577.9 |
# | timestep 647168 | policy   +0.917 | value   +2.118 | entropy   +0.380 | reward  +607.4 |
# | timestep 649216 | policy   +0.192 | value   +1.565 | entropy   +0.391 | reward  +591.0 |
# | timestep 651264 | policy   +0.512 | value   +1.821 | entropy   +0.400 | reward  +594.0 |
# | timestep 653312 | policy   +0.188 | value   +2.177 | entropy   +0.409 | reward  +597.5 |
# | timestep 655360 | policy   +0.500 | value   +1.779 | entropy   +0.418 | reward  +595.1 |
# | timestep 657408 | policy   +2.535 | value   +3.183 | entropy   +0.452 | reward  +599.3 |
# | timestep 659456 | policy   +2.470 | value   +3.507 | entropy   +0.494 | reward  +595.6 |
# | timestep 661504 | policy   +1.729 | value   +3.576 | entropy   +0.524 | reward  +588.8 |
# | timestep 663552 | policy   +1.584 | value   +3.038 | entropy   +0.546 | reward  +590.7 |
# | timestep 665600 | policy   +1.842 | value   +3.567 | entropy   +0.568 | reward  +571.4 |
# | timestep 667648 | policy   +0.954 | value   +3.741 | entropy   +0.583 | reward  +583.5 |
# | timestep 669696 | policy   +1.481 | value   +3.107 | entropy   +0.599 | reward  +592.0 |
# | timestep 671744 | policy   +0.111 | value   +2.227 | entropy   +0.611 | reward  +575.1 |
# | timestep 673792 | policy   +1.438 | value   +2.370 | entropy   +0.622 | reward  +585.0 |
# | timestep 675840 | policy   +1.640 | value   +3.058 | entropy   +0.646 | reward  +594.1 |
# | timestep 677888 | policy   +0.587 | value   +1.737 | entropy   +0.666 | reward  +580.0 |
# | timestep 679936 | policy   +1.521 | value   +2.950 | entropy   +0.686 | reward  +590.5 |
# | timestep 681984 | policy   +0.157 | value   +2.934 | entropy   +0.698 | reward  +591.5 |
# | timestep 684032 | policy   +0.757 | value   +3.331 | entropy   +0.704 | reward  +665.3 |
# | timestep 686080 | policy   +0.981 | value   +2.500 | entropy   +0.715 | reward  +592.4 |
# | timestep 688128 | policy   +0.692 | value   +2.279 | entropy   +0.727 | reward  +578.8 |
# | timestep 690176 | policy   -0.070 | value   +1.807 | entropy   +0.730 | reward  +577.9 |
# | timestep 692224 | policy   +2.917 | value   +2.769 | entropy   +0.746 | reward  +592.6 |
# | timestep 694272 | policy   +0.881 | value   +2.039 | entropy   +0.763 | reward  +558.1 |
# | timestep 696320 | policy   +2.205 | value   +3.202 | entropy   +0.771 | reward  +599.5 |
# | timestep 698368 | policy   +1.932 | value   +3.671 | entropy   +0.779 | reward  +630.6 |
# | timestep 700416 | policy   +0.926 | value   +2.345 | entropy   +0.786 | reward  +637.2 |
# | timestep 702464 | policy   -0.290 | value   +2.037 | entropy   +0.785 | reward  +680.2 |
# | timestep 704512 | policy   +0.227 | value   +2.012 | entropy   +0.782 | reward  +663.2 |
# | timestep 706560 | policy   +1.266 | value   +2.401 | entropy   +0.788 | reward  +638.9 |
# | timestep 708608 | policy   +2.190 | value   +3.438 | entropy   +0.798 | reward  +640.2 |
# | timestep 710656 | policy   +2.070 | value   +3.063 | entropy   +0.808 | reward  +647.1 |
# | timestep 712704 | policy   +0.392 | value   +2.321 | entropy   +0.814 | reward  +649.3 |
# | timestep 714752 | policy   +0.785 | value   +2.608 | entropy   +0.817 | reward  +658.0 |
# | timestep 716800 | policy   +0.748 | value   +1.883 | entropy   +0.822 | reward  +669.9 |
# | timestep 718848 | policy   +0.838 | value   +2.352 | entropy   +0.830 | reward  +585.5 |
# | timestep 720896 | policy   -0.735 | value   +2.576 | entropy   +0.822 | reward  +635.4 |
# | timestep 722944 | policy   +2.314 | value   +3.300 | entropy   +0.828 | reward  +695.0 |
# | timestep 724992 | policy   -0.216 | value   +2.672 | entropy   +0.833 | reward  +748.1 |
# | timestep 727040 | policy   +1.817 | value   +3.953 | entropy   +0.834 | reward  +687.5 |
# | timestep 729088 | policy   -1.904 | value   +2.072 | entropy   +0.817 | reward  +639.7 |
# | timestep 731136 | policy   +0.030 | value   +2.188 | entropy   +0.793 | reward  +722.9 |
# | timestep 733184 | policy   -0.540 | value   +1.783 | entropy   +0.781 | reward  +725.9 |
# | timestep 735232 | policy   -1.284 | value   +1.870 | entropy   +0.753 | reward  +723.5 |
# | timestep 737280 | policy   -1.056 | value   +1.560 | entropy   +0.718 | reward  +674.3 |
# | timestep 739328 | policy   +0.174 | value   +2.216 | entropy   +0.702 | reward  +778.0 |
# | timestep 741376 | policy   -1.485 | value   +1.659 | entropy   +0.680 | reward  +679.9 |
# | timestep 743424 | policy   -0.562 | value   +1.275 | entropy   +0.645 | reward  +682.8 |
# | timestep 745472 | policy   -0.086 | value   +1.707 | entropy   +0.631 | reward  +686.3 |
# | timestep 747520 | policy   -0.070 | value   +1.327 | entropy   +0.624 | reward  +638.9 |
# | timestep 749568 | policy   +0.672 | value   +2.019 | entropy   +0.632 | reward  +675.1 |
# | timestep 751616 | policy   -0.305 | value   +1.794 | entropy   +0.640 | reward  +604.7 |
# | timestep 753664 | policy   -0.198 | value   +1.913 | entropy   +0.632 | reward  +611.4 |
# | timestep 755712 | policy   -0.005 | value   +1.732 | entropy   +0.628 | reward  +595.0 |
# | timestep 757760 | policy   -0.011 | value   +2.168 | entropy   +0.624 | reward  +589.7 |
# | timestep 759808 | policy   +0.898 | value   +2.492 | entropy   +0.633 | reward  +633.4 |
# | timestep 761856 | policy   +0.418 | value   +2.144 | entropy   +0.649 | reward  +653.5 |
# | timestep 763904 | policy   +0.396 | value   +2.510 | entropy   +0.657 | reward  +613.8 |
# | timestep 765952 | policy   -0.337 | value   +1.607 | entropy   +0.655 | reward  +595.5 |
# | timestep 768000 | policy   -0.509 | value   +1.696 | entropy   +0.643 | reward  +609.8 |
# | timestep 770048 | policy   -0.647 | value   +1.012 | entropy   +0.621 | reward  +612.5 |
# | timestep 772096 | policy   -0.158 | value   +1.364 | entropy   +0.599 | reward  +721.8 |
# | timestep 774144 | policy   -0.768 | value   +1.203 | entropy   +0.578 | reward  +636.8 |
# | timestep 776192 | policy   +1.683 | value   +2.247 | entropy   +0.582 | reward  +613.1 |
# | timestep 778240 | policy   +0.726 | value   +1.373 | entropy   +0.610 | reward  +623.3 |
# | timestep 780288 | policy   -0.753 | value   +1.800 | entropy   +0.609 | reward  +608.4 |
# | timestep 782336 | policy   +0.668 | value   +1.860 | entropy   +0.604 | reward  +626.9 |
# | timestep 784384 | policy   +0.255 | value   +1.867 | entropy   +0.616 | reward  +593.0 |
# | timestep 786432 | policy   -0.437 | value   +1.305 | entropy   +0.612 | reward  +621.9 |
# | timestep 788480 | policy   +0.097 | value   +1.407 | entropy   +0.605 | reward  +605.6 |
# | timestep 790528 | policy   +0.440 | value   +1.733 | entropy   +0.614 | reward  +630.9 |
# | timestep 792576 | policy   +0.132 | value   +1.768 | entropy   +0.622 | reward  +659.8 |
# | timestep 794624 | policy   +1.376 | value   +2.233 | entropy   +0.643 | reward  +617.7 |
# | timestep 796672 | policy   +0.463 | value   +2.119 | entropy   +0.664 | reward  +627.7 |
# | timestep 798720 | policy   +0.974 | value   +1.824 | entropy   +0.682 | reward  +644.0 |
# | timestep 800768 | policy   -0.233 | value   +1.045 | entropy   +0.691 | reward  +616.7 |
# | timestep 802816 | policy   +0.337 | value   +1.811 | entropy   +0.690 | reward  +624.9 |
# | timestep 804864 | policy   +0.527 | value   +1.638 | entropy   +0.703 | reward  +626.4 |
# | timestep 806912 | policy   -0.179 | value   +1.082 | entropy   +0.706 | reward  +617.1 |
# | timestep 808960 | policy   +0.466 | value   +1.916 | entropy   +0.706 | reward  +634.9 |
# | timestep 811008 | policy   +0.893 | value   +1.612 | entropy   +0.726 | reward  +643.5 |
# | timestep 813056 | policy   +0.232 | value   +2.306 | entropy   +0.743 | reward  +606.8 |
# | timestep 815104 | policy   +1.962 | value   +1.949 | entropy   +0.762 | reward  +666.7 |
# | timestep 817152 | policy   +1.057 | value   +2.406 | entropy   +0.783 | reward  +666.4 |
# | timestep 819200 | policy   +1.554 | value   +2.827 | entropy   +0.792 | reward  +684.9 |
# | timestep 821248 | policy   +0.343 | value   +2.136 | entropy   +0.794 | reward  +640.7 |
# | timestep 823296 | policy   +0.025 | value   +2.738 | entropy   +0.788 | reward  +638.4 |
# | timestep 825344 | policy   +0.356 | value   +2.152 | entropy   +0.785 | reward  +655.0 |
# | timestep 827392 | policy   -0.074 | value   +2.585 | entropy   +0.784 | reward  +648.3 |
# | timestep 829440 | policy   +1.826 | value   +3.717 | entropy   +0.789 | reward  +657.9 |
# | timestep 831488 | policy   -0.273 | value   +1.816 | entropy   +0.787 | reward  +653.8 |
# | timestep 833536 | policy   -0.482 | value   +1.090 | entropy   +0.774 | reward  +648.8 |
# | timestep 835584 | policy   -0.128 | value   +2.104 | entropy   +0.762 | reward  +669.5 |
# | timestep 837632 | policy   +0.382 | value   +2.768 | entropy   +0.759 | reward  +676.2 |
# | timestep 839680 | policy   +0.622 | value   +2.085 | entropy   +0.768 | reward  +664.5 |
# | timestep 841728 | policy   -0.371 | value   +1.694 | entropy   +0.769 | reward  +663.2 |
# | timestep 843776 | policy   +0.864 | value   +2.300 | entropy   +0.771 | reward  +674.8 |
# | timestep 845824 | policy   -0.368 | value   +1.404 | entropy   +0.773 | reward  +655.5 |
# | timestep 847872 | policy   -0.405 | value   +1.679 | entropy   +0.757 | reward  +624.8 |
# | timestep 849920 | policy   -0.067 | value   +2.144 | entropy   +0.746 | reward  +646.6 |
# | timestep 851968 | policy   +0.237 | value   +1.714 | entropy   +0.748 | reward  +644.3 |
# | timestep 854016 | policy   +0.214 | value   +1.950 | entropy   +0.752 | reward  +631.1 |
# | timestep 856064 | policy   -0.259 | value   +2.275 | entropy   +0.749 | reward  +642.7 |
# | timestep 858112 | policy   +0.012 | value   +2.024 | entropy   +0.740 | reward  +671.2 |
# | timestep 860160 | policy   -0.265 | value   +1.418 | entropy   +0.730 | reward  +652.3 |
# | timestep 862208 | policy   +1.458 | value   +2.018 | entropy   +0.743 | reward  +663.1 |
# | timestep 864256 | policy   -0.400 | value   +1.334 | entropy   +0.752 | reward  +616.4 |
# | timestep 866304 | policy   +0.704 | value   +2.435 | entropy   +0.751 | reward  +658.5 |
# | timestep 868352 | policy   +0.215 | value   +1.959 | entropy   +0.758 | reward  +680.3 |
# | timestep 870400 | policy   +0.031 | value   +1.333 | entropy   +0.756 | reward  +633.4 |
# | timestep 872448 | policy   +0.915 | value   +2.109 | entropy   +0.764 | reward  +658.4 |
# | timestep 874496 | policy   -0.215 | value   +1.427 | entropy   +0.766 | reward  +632.9 |
# | timestep 876544 | policy   -0.109 | value   +1.518 | entropy   +0.757 | reward  +633.9 |
# | timestep 878592 | policy   +1.200 | value   +1.969 | entropy   +0.765 | reward  +612.9 |
# | timestep 880640 | policy   -0.035 | value   +1.424 | entropy   +0.772 | reward  +613.8 |
# | timestep 882688 | policy   -0.021 | value   +1.861 | entropy   +0.767 | reward  +600.7 |
# | timestep 884736 | policy   -0.125 | value   +1.572 | entropy   +0.761 | reward  +619.0 |
# | timestep 886784 | policy   +0.577 | value   +1.625 | entropy   +0.766 | reward  +637.5 |
# | timestep 888832 | policy   +0.603 | value   +1.728 | entropy   +0.773 | reward  +626.8 |
# | timestep 890880 | policy   +0.693 | value   +1.758 | entropy   +0.777 | reward  +610.7 |
# | timestep 892928 | policy   -0.159 | value   +1.281 | entropy   +0.774 | reward  +621.1 |
# | timestep 894976 | policy   +0.092 | value   +1.688 | entropy   +0.769 | reward  +612.7 |
# | timestep 897024 | policy   -0.042 | value   +1.535 | entropy   +0.765 | reward  +609.4 |
# | timestep 899072 | policy   +0.442 | value   +2.039 | entropy   +0.769 | reward  +611.7 |
# | timestep 901120 | policy   -0.259 | value   +1.846 | entropy   +0.766 | reward  +609.4 |
# | timestep 903168 | policy   +0.813 | value   +2.320 | entropy   +0.767 | reward  +609.3 |
# | timestep 905216 | policy   +0.126 | value   +2.031 | entropy   +0.771 | reward  +608.2 |
# | timestep 907264 | policy   +0.106 | value   +1.883 | entropy   +0.770 | reward  +615.7 |
# | timestep 909312 | policy   -0.207 | value   +1.922 | entropy   +0.762 | reward  +610.6 |
# | timestep 911360 | policy   -0.148 | value   +1.587 | entropy   +0.750 | reward  +637.6 |
# | timestep 913408 | policy   +0.417 | value   +2.407 | entropy   +0.755 | reward  +626.9 |
# | timestep 915456 | policy   -0.080 | value   +1.653 | entropy   +0.758 | reward  +628.6 |
# | timestep 917504 | policy   -0.274 | value   +1.601 | entropy   +0.749 | reward  +630.6 |
# | timestep 919552 | policy   +0.527 | value   +1.597 | entropy   +0.750 | reward  +622.2 |
# | timestep 921600 | policy   +0.756 | value   +1.616 | entropy   +0.763 | reward  +642.3 |
# | timestep 923648 | policy   +0.158 | value   +2.110 | entropy   +0.768 | reward  +652.2 |
# | timestep 925696 | policy   -0.575 | value   +1.836 | entropy   +0.756 | reward  +620.8 |
# | timestep 927744 | policy   +0.850 | value   +1.888 | entropy   +0.756 | reward  +615.1 |
# | timestep 929792 | policy   +0.405 | value   +2.153 | entropy   +0.768 | reward  +634.2 |
# | timestep 931840 | policy   -0.185 | value   +2.113 | entropy   +0.768 | reward  +628.4 |
# | timestep 933888 | policy   +1.035 | value   +2.038 | entropy   +0.773 | reward  +641.0 |
# | timestep 935936 | policy   +0.937 | value   +2.219 | entropy   +0.782 | reward  +635.6 |
# | timestep 937984 | policy   +1.301 | value   +2.076 | entropy   +0.788 | reward  +655.5 |
# | timestep 940032 | policy   +0.348 | value   +2.214 | entropy   +0.791 | reward  +626.0 |
# | timestep 942080 | policy   +1.809 | value   +2.763 | entropy   +0.796 | reward  +647.4 |
# | timestep 944128 | policy   +0.517 | value   +2.122 | entropy   +0.802 | reward  +641.8 |
# | timestep 946176 | policy   +1.346 | value   +3.025 | entropy   +0.806 | reward  +656.8 |
# | timestep 948224 | policy   +0.806 | value   +3.353 | entropy   +0.811 | reward  +617.4 |
# | timestep 950272 | policy   +1.412 | value   +3.287 | entropy   +0.817 | reward  +619.2 |
# | timestep 952320 | policy   -0.651 | value   +2.453 | entropy   +0.812 | reward  +642.7 |
# | timestep 954368 | policy   +0.495 | value   +2.759 | entropy   +0.808 | reward  +627.2 |
# | timestep 956416 | policy   -0.385 | value   +2.324 | entropy   +0.805 | reward  +651.0 |
# | timestep 958464 | policy   -0.537 | value   +2.094 | entropy   +0.792 | reward  +626.6 |
# | timestep 960512 | policy   -0.893 | value   +1.651 | entropy   +0.771 | reward  +624.2 |
# | timestep 962560 | policy   -0.054 | value   +1.585 | entropy   +0.755 | reward  +601.0 |
# | timestep 964608 | policy   -0.332 | value   +1.908 | entropy   +0.745 | reward  +641.5 |
# | timestep 966656 | policy   -0.156 | value   +1.639 | entropy   +0.734 | reward  +637.3 |
# | timestep 968704 | policy   +0.725 | value   +1.842 | entropy   +0.744 | reward  +600.1 |
# | timestep 970752 | policy   +1.355 | value   +2.925 | entropy   +0.769 | reward  +629.7 |
# | timestep 972800 | policy   +0.588 | value   +2.174 | entropy   +0.784 | reward  +645.5 |
# | timestep 974848 | policy   +0.304 | value   +2.038 | entropy   +0.789 | reward  +666.1 |
# | timestep 976896 | policy   -0.385 | value   +2.890 | entropy   +0.788 | reward  +666.9 |
# | timestep 978944 | policy   -0.074 | value   +1.624 | entropy   +0.781 | reward  +682.1 |
# | timestep 980992 | policy   -0.167 | value   +1.948 | entropy   +0.772 | reward  +690.3 |
# | timestep 983040 | policy   +0.261 | value   +1.828 | entropy   +0.768 | reward  +654.3 |
# | timestep 985088 | policy   +0.268 | value   +2.121 | entropy   +0.770 | reward  +642.6 |
# | timestep 987136 | policy   -0.757 | value   +1.885 | entropy   +0.761 | reward  +645.2 |
# | timestep 989184 | policy   +1.154 | value   +2.458 | entropy   +0.763 | reward  +613.0 |
# | timestep 991232 | policy   +0.714 | value   +2.665 | entropy   +0.781 | reward  +674.2 |
# | timestep 993280 | policy   +0.055 | value   +1.492 | entropy   +0.787 | reward  +698.2 |
# | timestep 995328 | policy   +0.263 | value   +1.985 | entropy   +0.788 | reward  +637.5 |
# | timestep 997376 | policy   -0.405 | value   +1.939 | entropy   +0.782 | reward  +694.5 |
# | timestep 999424 | policy   +0.263 | value   +2.020 | entropy   +0.775 | reward  +638.2 |
# | timestep 1001472 | policy   -0.358 | value   +1.650 | entropy   +0.766 | reward  +656.9 |
# | timestep 1003520 | policy   -0.199 | value   +2.395 | entropy   +0.752 | reward  +658.8 |
# | timestep 1005568 | policy   +0.064 | value   +1.720 | entropy   +0.749 | reward  +674.4 |
# | timestep 1007616 | policy   -0.520 | value   +1.802 | entropy   +0.742 | reward  +651.8 |
# | timestep 1009664 | policy   +0.493 | value   +1.904 | entropy   +0.738 | reward  +657.4 |
# | timestep 1011712 | policy   +0.263 | value   +2.099 | entropy   +0.746 | reward  +649.0 |
# | timestep 1013760 | policy   +1.479 | value   +2.527 | entropy   +0.762 | reward  +595.5 |
# | timestep 1015808 | policy   +0.246 | value   +2.612 | entropy   +0.771 | reward  +661.1 |
# | timestep 1017856 | policy   -0.145 | value   +2.478 | entropy   +0.767 | reward  +631.1 |
# | timestep 1019904 | policy   +0.178 | value   +1.643 | entropy   +0.765 | reward  +649.2 |
# | timestep 1021952 | policy   +0.292 | value   +2.590 | entropy   +0.767 | reward  +664.6 |
# | timestep 1024000 | policy   -0.193 | value   +2.884 | entropy   +0.760 | reward  +639.5 |
# | timestep 1026048 | policy   -0.489 | value   +1.988 | entropy   +0.745 | reward  +655.6 |
# | timestep 1028096 | policy   +0.436 | value   +2.228 | entropy   +0.739 | reward  +665.4 |
# | timestep 1030144 | policy   -0.395 | value   +2.378 | entropy   +0.735 | reward  +648.1 |
# | timestep 1032192 | policy   -0.905 | value   +1.974 | entropy   +0.715 | reward  +638.3 |
# | timestep 1034240 | policy   -0.308 | value   +1.824 | entropy   +0.695 | reward  +661.2 |
# | timestep 1036288 | policy   -0.091 | value   +2.137 | entropy   +0.683 | reward  +657.1 |
# | timestep 1038336 | policy   +0.401 | value   +1.868 | entropy   +0.684 | reward  +650.3 |
# | timestep 1040384 | policy   +0.485 | value   +1.520 | entropy   +0.697 | reward  +646.0 |
# | timestep 1042432 | policy   -0.351 | value   +1.900 | entropy   +0.699 | reward  +646.9 |
# | timestep 1044480 | policy   -0.146 | value   +2.171 | entropy   +0.688 | reward  +625.9 |
# | timestep 1046528 | policy   -0.638 | value   +1.778 | entropy   +0.668 | reward  +633.0 |
# | timestep 1048576 | policy   +0.167 | value   +1.835 | entropy   +0.657 | reward  +650.5 |
# | timestep 1050624 | policy   +0.270 | value   +1.401 | entropy   +0.664 | reward  +651.5 |
# | timestep 1052672 | policy   +1.341 | value   +2.187 | entropy   +0.686 | reward  +628.1 |
# | timestep 1054720 | policy   -0.690 | value   +1.842 | entropy   +0.691 | reward  +635.2 |
# | timestep 1056768 | policy   +0.662 | value   +2.163 | entropy   +0.687 | reward  +668.6 |
# | timestep 1058816 | policy   +0.693 | value   +1.496 | entropy   +0.705 | reward  +644.6 |
# | timestep 1060864 | policy   +0.546 | value   +1.490 | entropy   +0.721 | reward  +623.2 |
# | timestep 1062912 | policy   +0.814 | value   +1.633 | entropy   +0.738 | reward  +618.3 |
# | timestep 1064960 | policy   +0.940 | value   +2.378 | entropy   +0.757 | reward  +644.6 |
# | timestep 1067008 | policy   +0.544 | value   +2.103 | entropy   +0.766 | reward  +662.0 |
# ...
# | timestep 1146880 | policy   +1.325 | value   +4.824 | entropy   +0.665 | reward  +648.9 |
# | timestep 1148928 | policy   -1.353 | value   +5.535 | entropy   +0.666 | reward  +634.4 |
# | timestep 1150976 | policy   +1.302 | value   +4.967 | entropy   +0.664 | reward  +659.7 |
# | timestep 1153024 | policy   -0.970 | value   +5.101 | entropy   +0.664 | reward  +635.7 |
# | timestep 1155072 | policy   +0.091 | value   +5.518 | entropy   +0.658 | reward  +604.7 |
# | timestep 1157120 | policy   +2.382 | value   +4.199 | entropy   +0.674 | reward  +626.8 |
# | timestep 1159168 | policy   +1.562 | value   +4.883 | entropy   +0.697 | reward  +639.2 |
# | timestep 1161216 | policy   -1.958 | value   +4.919 | entropy   +0.691 | reward  +718.4 |
# | timestep 1163264 | policy   -0.201 | value   +6.665 | entropy   +0.676 | reward  +669.5 |
# | timestep 1165312 | policy   -2.921 | value   +5.878 | entropy   +0.657 | reward  +656.0 |
# | timestep 1167360 | policy   +3.389 | value   +6.613 | entropy   +0.659 | reward  +763.6 |
# | timestep 1169408 | policy   +2.514 | value   +6.229 | entropy   +0.683 | reward  +645.4 |
# | timestep 1171456 | policy   +3.656 | value   +4.673 | entropy   +0.706 | reward  +594.3 |
# | timestep 1173504 | policy   +0.948 | value   +4.798 | entropy   +0.723 | reward  +644.2 |
# | timestep 1175552 | policy   +3.360 | value   +6.973 | entropy   +0.736 | reward  +633.8 |
# | timestep 1177600 | policy   +3.136 | value   +4.457 | entropy   +0.755 | reward  +713.7 |
# | timestep 1179648 | policy   +3.244 | value   +6.739 | entropy   +0.771 | reward  +632.5 |
# | timestep 1181696 | policy   +1.885 | value   +4.998 | entropy   +0.782 | reward  +718.6 |
# | timestep 1183744 | policy   +1.950 | value   +5.212 | entropy   +0.792 | reward  +795.1 |
# | timestep 1185792 | policy   -0.311 | value   +5.471 | entropy   +0.797 | reward  +677.2 |
# | timestep 1187840 | policy   +1.064 | value   +5.324 | entropy   +0.800 | reward  +642.1 |
# | timestep 1189888 | policy   +3.224 | value   +6.311 | entropy   +0.813 | reward  +663.8 |
# | timestep 1191936 | policy   +0.116 | value   +4.972 | entropy   +0.818 | reward  +903.5 |
# | timestep 1193984 | policy   +1.139 | value   +5.100 | entropy   +0.820 | reward  +635.9 |
# | timestep 1196032 | policy   -0.124 | value   +5.689 | entropy   +0.819 | reward +1022.2 |
# | timestep 1198080 | policy   +2.326 | value   +4.412 | entropy   +0.824 | reward  +625.8 |
# | timestep 1200128 | policy   +0.868 | value   +6.683 | entropy   +0.832 | reward  +604.9 |
# | timestep 1202176 | policy   -0.443 | value   +6.787 | entropy   +0.828 | reward  +709.3 |
# | timestep 1204224 | policy   -0.160 | value   +5.786 | entropy   +0.820 | reward  +636.7 |
# | timestep 1206272 | policy   +1.947 | value   +5.827 | entropy   +0.823 | reward  +747.5 |
# | timestep 1208320 | policy   -0.760 | value   +6.121 | entropy   +0.824 | reward +1048.7 |
# | timestep 1210368 | policy   +3.965 | value   +6.115 | entropy   +0.829 | reward  +716.3 |
# | timestep 1212416 | policy   +0.883 | value   +6.074 | entropy   +0.840 | reward  +698.2 |
# | timestep 1214464 | policy   -0.419 | value   +5.946 | entropy   +0.837 | reward  +714.9 |
# | timestep 1216512 | policy   -0.139 | value   +6.506 | entropy   +0.831 | reward  +694.7 |
# | timestep 1218560 | policy   -1.221 | value   +5.909 | entropy   +0.822 | reward  +733.6 |
# | timestep 1220608 | policy   +2.686 | value   +6.241 | entropy   +0.830 | reward  +921.1 |
# | timestep 1222656 | policy   +0.539 | value   +5.159 | entropy   +0.842 | reward +1093.2 |
# | timestep 1224704 | policy   +2.047 | value   +6.055 | entropy   +0.845 | reward  +746.7 |
# | timestep 1226752 | policy   +1.725 | value   +5.826 | entropy   +0.849 | reward  +743.2 |
# | timestep 1228800 | policy   +2.917 | value   +5.881 | entropy   +0.854 | reward  +574.6 |
# | timestep 1230848 | policy   -0.329 | value   +6.097 | entropy   +0.854 | reward  +680.3 |
# | timestep 1232896 | policy   +1.077 | value   +5.420 | entropy   +0.852 | reward  +980.2 |
# | timestep 1234944 | policy   +0.643 | value   +4.714 | entropy   +0.853 | reward +1158.7 |
# | timestep 1236992 | policy   +1.046 | value   +5.062 | entropy   +0.854 | reward  +913.7 |
# | timestep 1239040 | policy   -1.649 | value   +5.804 | entropy   +0.844 | reward +1133.0 |
# | timestep 1241088 | policy   +1.500 | value   +5.125 | entropy   +0.838 | reward  +711.9 |
# | timestep 1243136 | policy   -0.451 | value   +5.371 | entropy   +0.836 | reward  +660.6 |
# | timestep 1245184 | policy   +0.361 | value   +5.350 | entropy   +0.831 | reward  +750.7 |
# | timestep 1247232 | policy   -0.389 | value   +6.151 | entropy   +0.830 | reward +1040.1 |
# | timestep 1249280 | policy   +1.342 | value   +5.600 | entropy   +0.834 | reward +1103.2 |
# | timestep 1251328 | policy   +0.262 | value   +4.909 | entropy   +0.839 | reward +1274.9 |
# | timestep 1253376 | policy   +0.024 | value   +5.757 | entropy   +0.835 | reward +1395.8 |
# | timestep 1255424 | policy   +3.088 | value   +6.803 | entropy   +0.843 | reward +1010.2 |
# | timestep 1257472 | policy   +2.279 | value   +5.621 | entropy   +0.857 | reward  +855.5 |
# | timestep 1259520 | policy   -1.151 | value   +6.212 | entropy   +0.853 | reward +1357.5 |
# | timestep 1261568 | policy   +2.134 | value   +6.073 | entropy   +0.855 | reward +1055.7 |
# | timestep 1263616 | policy   +0.957 | value   +5.774 | entropy   +0.862 | reward  +825.1 |
# | timestep 1265664 | policy   +0.779 | value   +5.766 | entropy   +0.863 | reward  +686.8 |
# | timestep 1267712 | policy   -2.489 | value   +6.437 | entropy   +0.847 | reward +1495.3 |
# | timestep 1269760 | policy   +1.714 | value   +5.989 | entropy   +0.841 | reward +1077.9 |
# | timestep 1271808 | policy   +0.310 | value   +6.443 | entropy   +0.854 | reward +1821.1 |
# | timestep 1273856 | policy   -0.121 | value   +6.992 | entropy   +0.851 | reward +1147.2 |
# | timestep 1275904 | policy   +1.930 | value   +6.619 | entropy   +0.851 | reward +1710.8 |
# | timestep 1277952 | policy   -0.734 | value   +6.435 | entropy   +0.847 | reward +1494.7 |
# | timestep 1280000 | policy   +2.737 | value   +6.919 | entropy   +0.850 | reward +1261.3 |
# | timestep 1282048 | policy   +0.670 | value   +7.572 | entropy   +0.858 | reward +1094.1 |
# | timestep 1284096 | policy   +2.293 | value   +6.646 | entropy   +0.863 | reward +1136.8 |
# | timestep 1286144 | policy   +0.322 | value   +7.070 | entropy   +0.866 | reward +1507.3 |
# | timestep 1288192 | policy   +1.587 | value   +6.537 | entropy   +0.866 | reward +1606.9 |
# | timestep 1290240 | policy   +0.565 | value   +5.136 | entropy   +0.868 | reward +1938.3 |
# | timestep 1292288 | policy   -0.263 | value   +6.485 | entropy   +0.867 | reward +1598.5 |
# | timestep 1294336 | policy   +0.042 | value   +5.302 | entropy   +0.862 | reward +1542.1 |
# | timestep 1296384 | policy   +3.406 | value   +6.235 | entropy   +0.869 | reward +1317.8 |
# | timestep 1298432 | policy   +3.711 | value   +4.875 | entropy   +0.879 | reward +1172.9 |
# | timestep 1300480 | policy   +3.269 | value   +5.560 | entropy   +0.887 | reward  +919.1 |
# | timestep 1302528 | policy   +3.745 | value   +7.534 | entropy   +0.893 | reward +1411.2 |
# | timestep 1304576 | policy   +4.336 | value   +6.372 | entropy   +0.899 | reward +1303.4 |
# | timestep 1306624 | policy   +0.911 | value   +7.443 | entropy   +0.903 | reward +1519.2 |
# | timestep 1308672 | policy   +0.906 | value   +7.333 | entropy   +0.903 | reward +1587.0 |
# | timestep 1310720 | policy   +1.814 | value   +6.500 | entropy   +0.904 | reward +1289.4 |
# | timestep 1312768 | policy   +0.400 | value   +6.284 | entropy   +0.904 | reward  +766.8 |
# | timestep 1314816 | policy   -0.661 | value   +4.894 | entropy   +0.898 | reward +1052.3 |
# | timestep 1316864 | policy   +1.990 | value   +5.458 | entropy   +0.901 | reward +1103.6 |
# | timestep 1318912 | policy   -1.244 | value   +5.443 | entropy   +0.897 | reward +1672.7 |
# | timestep 1320960 | policy   -0.199 | value   +5.990 | entropy   +0.886 | reward +1019.9 |
# | timestep 1323008 | policy   +3.948 | value   +6.503 | entropy   +0.896 | reward +1300.9 |
# | timestep 1325056 | policy   -0.138 | value   +5.985 | entropy   +0.900 | reward +1259.6 |
# | timestep 1327104 | policy   -1.580 | value   +6.013 | entropy   +0.885 | reward +1019.9 |
# | timestep 1329152 | policy   -1.535 | value   +7.615 | entropy   +0.863 | reward +1331.6 |
# | timestep 1331200 | policy   -0.690 | value   +6.587 | entropy   +0.846 | reward +1983.6 |
# | timestep 1333248 | policy   +0.628 | value   +5.820 | entropy   +0.838 | reward +1259.7 |
# | timestep 1335296 | policy   +1.367 | value   +6.457 | entropy   +0.843 | reward +1492.7 |
# | timestep 1337344 | policy   +0.100 | value   +6.716 | entropy   +0.846 | reward +1300.0 |
# | timestep 1339392 | policy   +2.643 | value   +7.821 | entropy   +0.855 | reward +1068.7 |
# | timestep 1341440 | policy   +2.636 | value   +5.372 | entropy   +0.874 | reward +1555.1 |
# | timestep 1343488 | policy   +1.322 | value   +6.713 | entropy   +0.882 | reward +1084.8 |
# | timestep 1345536 | policy   +1.214 | value   +5.758 | entropy   +0.884 | reward +1344.1 |
# | timestep 1347584 | policy   +1.559 | value   +7.299 | entropy   +0.886 | reward +1412.7 |
# | timestep 1349632 | policy   -2.244 | value   +6.827 | entropy   +0.874 | reward +1159.0 |
# | timestep 1351680 | policy   -0.497 | value   +5.371 | entropy   +0.854 | reward +1458.8 |
# | timestep 1353728 | policy   +0.027 | value   +6.518 | entropy   +0.847 | reward +1053.1 |
# | timestep 1355776 | policy   +2.331 | value   +5.283 | entropy   +0.856 | reward +1604.2 |
# | timestep 1357824 | policy   +0.180 | value   +6.704 | entropy   +0.867 | reward  +939.5 |
# | timestep 1359872 | policy   +1.038 | value   +6.795 | entropy   +0.869 | reward +2137.1 |
# | timestep 1361920 | policy   +2.288 | value   +6.088 | entropy   +0.875 | reward +1053.0 |
# | timestep 1363968 | policy   +1.242 | value   +5.356 | entropy   +0.878 | reward +2212.2 |
# | timestep 1366016 | policy   +1.149 | value   +5.901 | entropy   +0.877 | reward +1825.9 |
# | timestep 1368064 | policy   +0.138 | value   +5.875 | entropy   +0.874 | reward +1824.9 |
# | timestep 1370112 | policy   +3.405 | value   +6.886 | entropy   +0.879 | reward +1075.9 |
# | timestep 1372160 | policy   +3.037 | value   +4.644 | entropy   +0.890 | reward +1593.3 |
# | timestep 1374208 | policy   -0.016 | value   +5.741 | entropy   +0.892 | reward +1549.1 |
# | timestep 1376256 | policy   +0.693 | value   +4.476 | entropy   +0.891 | reward +1155.7 |
# | timestep 1378304 | policy   +2.824 | value   +6.822 | entropy   +0.893 | reward +2283.1 |
# | timestep 1380352 | policy   +2.314 | value   +6.914 | entropy   +0.896 | reward  +888.7 |
# | timestep 1382400 | policy   +0.677 | value   +6.022 | entropy   +0.900 | reward +1554.8 |
# | timestep 1384448 | policy   +2.928 | value   +7.178 | entropy   +0.904 | reward +1847.8 |
# | timestep 1386496 | policy   +1.179 | value   +6.486 | entropy   +0.906 | reward +1985.4 |
# | timestep 1388544 | policy   +2.004 | value   +6.329 | entropy   +0.905 | reward +1995.3 |
# | timestep 1390592 | policy   +4.525 | value   +5.991 | entropy   +0.908 | reward +1684.5 |
# | timestep 1392640 | policy   +0.916 | value   +7.131 | entropy   +0.908 | reward +1914.4 |
# | timestep 1394688 | policy   +0.587 | value   +7.182 | entropy   +0.906 | reward +1270.3 |
# | timestep 1396736 | policy   +2.424 | value   +5.738 | entropy   +0.907 | reward +1931.2 |
# | timestep 1398784 | policy   -0.425 | value   +6.183 | entropy   +0.905 | reward +1658.5 |
# | timestep 1400832 | policy   +1.541 | value   +5.893 | entropy   +0.904 | reward  +943.3 |
# | timestep 1402880 | policy   +0.880 | value   +6.537 | entropy   +0.905 | reward +1294.6 |
# | timestep 1404928 | policy   +2.137 | value   +6.146 | entropy   +0.906 | reward +1972.5 |
# | timestep 1406976 | policy   +0.814 | value   +7.081 | entropy   +0.908 | reward +2232.8 |
# | timestep 1409024 | policy   +5.010 | value   +6.755 | entropy   +0.908 | reward +2263.2 |
# | timestep 1411072 | policy   -0.112 | value   +6.858 | entropy   +0.906 | reward +1994.4 |
# | timestep 1413120 | policy   +0.959 | value   +5.224 | entropy   +0.904 | reward +1486.5 |
# | timestep 1415168 | policy   -1.175 | value   +5.847 | entropy   +0.898 | reward +1629.1 |
# | timestep 1417216 | policy   -0.019 | value   +7.271 | entropy   +0.892 | reward +1876.5 |
# | timestep 1419264 | policy   +1.824 | value   +6.800 | entropy   +0.898 | reward +1399.7 |
# | timestep 1421312 | policy   +1.701 | value   +6.747 | entropy   +0.901 | reward +1178.8 |
# | timestep 1423360 | policy   +1.889 | value   +7.320 | entropy   +0.902 | reward +1842.4 |
# | timestep 1425408 | policy   +5.389 | value   +7.394 | entropy   +0.905 | reward +2122.9 |
# | timestep 1427456 | policy   +2.299 | value   +7.358 | entropy   +0.907 | reward  +981.1 |
# | timestep 1429504 | policy   +0.024 | value   +6.571 | entropy   +0.904 | reward +1806.5 |
# | timestep 1431552 | policy   +2.906 | value   +5.815 | entropy   +0.905 | reward +1813.9 |
# | timestep 1433600 | policy   -0.098 | value   +5.970 | entropy   +0.904 | reward +1746.2 |
# | timestep 1435648 | policy   +0.073 | value   +5.002 | entropy   +0.902 | reward +1874.7 |
# | timestep 1437696 | policy   +1.577 | value   +5.885 | entropy   +0.903 | reward +1840.4 |
# | timestep 1439744 | policy   +0.648 | value   +6.153 | entropy   +0.904 | reward +1911.8 |
# | timestep 1441792 | policy   +1.253 | value   +7.170 | entropy   +0.905 | reward +1839.0 |
# | timestep 1443840 | policy   +2.761 | value   +6.829 | entropy   +0.907 | reward +2194.4 |
# | timestep 1445888 | policy   +1.643 | value   +5.899 | entropy   +0.908 | reward +1848.7 |
# | timestep 1447936 | policy   +1.782 | value   +6.307 | entropy   +0.908 | reward +2052.2 |
# | timestep 1449984 | policy   +3.751 | value   +6.459 | entropy   +0.908 | reward +2026.5 |
# | timestep 1452032 | policy   +3.929 | value   +7.147 | entropy   +0.908 | reward +1241.0 |
# | timestep 1454080 | policy   -0.084 | value   +6.786 | entropy   +0.906 | reward +1181.0 |
# | timestep 1456128 | policy   +0.623 | value   +6.874 | entropy   +0.905 | reward +2240.8 |
# | timestep 1458176 | policy   +0.648 | value   +4.359 | entropy   +0.906 | reward +2156.8 |
# | timestep 1460224 | policy   +0.033 | value   +6.349 | entropy   +0.906 | reward +2260.1 |
# | timestep 1462272 | policy   +1.843 | value   +5.356 | entropy   +0.907 | reward +1927.2 |
# | timestep 1464320 | policy   +3.332 | value   +5.291 | entropy   +0.908 | reward +1884.0 |
# | timestep 1466368 | policy   +0.703 | value   +6.618 | entropy   +0.907 | reward +1786.2 |
# | timestep 1468416 | policy   +0.785 | value   +6.944 | entropy   +0.905 | reward +1831.8 |
# | timestep 1470464 | policy   -0.057 | value   +8.328 | entropy   +0.901 | reward +1516.5 |
# | timestep 1472512 | policy   +2.003 | value   +6.706 | entropy   +0.903 | reward +2085.8 |
# | timestep 1474560 | policy   -0.285 | value   +6.983 | entropy   +0.900 | reward +1987.8 |
# | timestep 1476608 | policy   +1.678 | value   +8.476 | entropy   +0.897 | reward +1967.3 |
# | timestep 1478656 | policy   +2.232 | value   +6.265 | entropy   +0.901 | reward +2248.2 |
# | timestep 1480704 | policy   +0.902 | value   +5.915 | entropy   +0.903 | reward +2219.1 |
# | timestep 1482752 | policy   -0.676 | value   +6.581 | entropy   +0.902 | reward +2306.2 |
# | timestep 1484800 | policy   +0.387 | value   +6.673 | entropy   +0.899 | reward +2319.9 |
# | timestep 1486848 | policy   +3.176 | value   +6.669 | entropy   +0.901 | reward +2300.9 |
# | timestep 1488896 | policy   +3.663 | value   +8.710 | entropy   +0.905 | reward +1556.3 |
# | timestep 1490944 | policy   +1.916 | value   +8.643 | entropy   +0.907 | reward +1668.7 |
# | timestep 1492992 | policy   +2.213 | value   +7.112 | entropy   +0.907 | reward +2329.2 |
# | timestep 1495040 | policy   +0.569 | value   +6.488 | entropy   +0.906 | reward +2222.7 |
# | timestep 1497088 | policy   +1.935 | value   +6.064 | entropy   +0.906 | reward +2269.6 |
# | timestep 1499136 | policy   +0.512 | value   +5.766 | entropy   +0.906 | reward +1872.0 |

# %%
policy.load("./model_weights/Walker2d-v4")

# %%
env = gym.make('Walker2d-v4', render_mode=None)
mean, std = evaluate(policy, env, eval_num=32)
env.close()

print('mean : %f    std : %f'%(mean, std))
# Out:
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment Walker2d-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# mean : 1297.899658    std : 558.031799

# %%
env = gym.make('Walker2d-v4', render_mode='human')
total_reward, _ = evaluate(policy, env, eval_num=1, deterministic=True)
env.close()
# Out:
# /Users/pietrosig/RL_PROJECT/.venv/lib/python3.10/site-packages/glfw/__init__.py:917: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)
